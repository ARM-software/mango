# %% [markdown]
# # Testing Mango

# %%
from mango.tuner import Tuner

# %%
from mango.domain.distribution import loguniform

param_dict = {"changepoint_prior_scale": loguniform(-3, 1),
              'seasonality_prior_scale' : loguniform(-1, 2)
             }

# %% [markdown]
# # userObjective on Celery

# %%
from mango.examples.classifiers.CeleryTasks import run_prophet



iteration_count = 1

def objective_Prophet(args_list):
    global iteration_count
    
    print('iteration_count:',iteration_count)
    
    iteration_count = iteration_count+1
    process_queue =[]
    
    for hyper_par in args_list:
        process = run_prophet.delay(hyper_par)
        process_queue.append(process)
    
    results = []
    for process in process_queue:
        result = process.get(timeout=100)
        results.append(result)
           
    return results
# Out:
# ERROR:fbprophet:Importing plotly failed. Interactive plots will not work.

# %%
conf_Dict = dict()
conf_Dict['batch_size'] = 4
conf_Dict['num_iteration'] = 10

# %% [markdown]
# # Defining Tuner

# %%
tuner_user = Tuner(param_dict, objective_Prophet,conf_Dict)

# %%
tuner_user.getConf()
# Out:
# {'param_dict': {'changepoint_prior_scale': <scipy.stats._distn_infrastructure.rv_frozen at 0x115b88320>,
#   'seasonality_prior_scale': <scipy.stats._distn_infrastructure.rv_frozen at 0x115b887b8>},
#  'userObjective': <function __main__.objective_Prophet(args_list)>,
#  'domain_size': 5000,
#  'initial_random': 1,
#  'num_iteration': 10,
#  'objective': 'maximize',
#  'batch_size': 4}

# %%
results = tuner_user.run()
# Out:
# iteration_count: 1
# iteration_count: 2
# iteration_count: 3
# iteration_count: 4
# iteration_count: 5
# iteration_count: 6
# iteration_count: 7
# iteration_count: 8
# iteration_count: 9
# iteration_count: 10
# iteration_count: 11

# %% [markdown]
# # Inspect the results

# %%
print('best hyper parameters:',results['best_hyper_parameter'])
print('best objective:',results['best_objective'])
# Out:
# best hyper parameters: {'changepoint_prior_scale': 0.002786394422366743, 'seasonality_prior_scale': 3.738159390189678}
# best objective: -9.984134991879408

# %%
print('Sample hyper parameters tried:',len(results['hyper_parameters_tried']))
print(results['hyper_parameters_tried'][:2])
# Out:
# Sample hyper parameters tried: 41
# [{'changepoint_prior_scale': 0.005649591062579136, 'seasonality_prior_scale': 5.307351287160325}, {'changepoint_prior_scale': 0.005467268371601695, 'seasonality_prior_scale': 0.10000364543964525}]

# %%
print('Sample objective values',len(results['objective_values']))
print(results['objective_values'][:5])
# Out:
# Sample objective values 41
# [-10.004180798868088, -10.024311710980166, -10.023008713906927, -10.04998677853578, -10.61235085924873]

# %% [markdown]
# # Plotting the actual variation in objective values of the tried results

# %%
Size = 201 

from matplotlib import pyplot as plt
fig = plt.figure(figsize=(30,5))
plt.title('Variation of Objective',fontsize=20)
plt.plot(results['objective_values'][:Size],lw=4,label='BL')
plt.xlabel('Configurations', fontsize=25)
plt.ylabel('objective_values',fontsize=25)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.legend(prop={'size': 30})
plt.show()

# %% [markdown]
# # Plotting the variation of Max objective values of the tried results

# %%
Size = 201 

import numpy as np

results_obj = np.array(results['objective_values'])

y_max=[]
for i in range(results_obj.shape[0]):
    y_max.append(np.max(results_obj[:i+1]))

from matplotlib import pyplot as plt
fig = plt.figure(figsize=(30,5))
plt.title('Max variation of Objective',fontsize=20)
plt.plot(y_max[:Size],lw=4,label='BL')
plt.xlabel('Configurations', fontsize=25)
plt.ylabel('objective_values',fontsize=25)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.legend(prop={'size': 30})
plt.show()

# %% [markdown]
# # See the Result

# %%
import pprint
pp = pprint.PrettyPrinter(indent=4)
pp.pprint(results)
# Out:
# {   'best_hyper_parameter': {   'changepoint_prior_scale': 0.002786394422366743,
#                                 'seasonality_prior_scale': 3.738159390189678},
#     'best_objective': -9.984134991879408,
#     'hyper_parameters_tried': [   {   'changepoint_prior_scale': 0.005649591062579136,
#                                       'seasonality_prior_scale': 5.307351287160325},
#                                   {   'changepoint_prior_scale': 0.005467268371601695,
#                                       'seasonality_prior_scale': 0.10000364543964525},
#                                   {   'changepoint_prior_scale': 0.005815680093340823,
#                                       'seasonality_prior_scale': 9.121462413562544},
#                                   {   'changepoint_prior_scale': 0.0023963448473905313,
#                                       'seasonality_prior_scale': 0.10443618513965951},
#                                   {   'changepoint_prior_scale': 0.0012728066835953962,
#                                       'seasonality_prior_scale': 4.933545099549162},
#                                   {   'changepoint_prior_scale': 0.004473190203742817,
#                                       'seasonality_prior_scale': 2.550543900093717},
#                                   {   'changepoint_prior_scale': 0.0013993873827208945,
#                                       'seasonality_prior_scale': 7.2205498578083},
#                                   {   'changepoint_prior_scale': 0.005500690458350502,
#                                       'seasonality_prior_scale': 1.358489894140267},
#                                   {   'changepoint_prior_scale': 0.002786394422366743,
#                                       'seasonality_prior_scale': 3.738159390189678},
#                                   {   'changepoint_prior_scale': 0.001218609848528341,
#                                       'seasonality_prior_scale': 6.260173528885017},
#                                   {   'changepoint_prior_scale': 0.00241780040072473,
#                                       'seasonality_prior_scale': 8.171841822966195},
#                                   {   'changepoint_prior_scale': 0.0097187287881883,
#                                       'seasonality_prior_scale': 9.980057058057143},
#                                   {   'changepoint_prior_scale': 0.009147470989003316,
#                                       'seasonality_prior_scale': 1.952565676621266},
#                                   {   'changepoint_prior_scale': 0.004634346796979472,
#                                       'seasonality_prior_scale': 4.334684645313109},
#                                   {   'changepoint_prior_scale': 0.009169693271976349,
#                                       'seasonality_prior_scale': 3.14411153263723},
#                                   {   'changepoint_prior_scale': 0.009748420341160857,
#                                       'seasonality_prior_scale': 0.7736399992493356},
#                                   {   'changepoint_prior_scale': 0.005980112724919232,
#                                       'seasonality_prior_scale': 6.735736646380398},
#                                   {   'changepoint_prior_scale': 0.009815475495259438,
#                                       'seasonality_prior_scale': 8.649153872759637},
#                                   {   'changepoint_prior_scale': 0.009100187448104308,
#                                       'seasonality_prior_scale': 7.695952594302281},
#                                   {   'changepoint_prior_scale': 0.0013768430716398596,
#                                       'seasonality_prior_scale': 5.7864072128011},
#                                   {   'changepoint_prior_scale': 0.0026916153161462945,
#                                       'seasonality_prior_scale': 9.568992640988066},
#                                   {   'changepoint_prior_scale': 0.00913822973931074,
#                                       'seasonality_prior_scale': 0.46054890472287763},
#                                   {   'changepoint_prior_scale': 0.0011705729359183276,
#                                       'seasonality_prior_scale': 2.2560141341942415},
#                                   {   'changepoint_prior_scale': 0.007977014876145345,
#                                       'seasonality_prior_scale': 4.032576425840591},
#                                   {   'changepoint_prior_scale': 0.001197604387898326,
#                                       'seasonality_prior_scale': 1.6407682622599307},
#                                   {   'changepoint_prior_scale': 0.0026243346178488097,
#                                       'seasonality_prior_scale': 3.4330172976162165},
#                                   {   'changepoint_prior_scale': 0.0050024801795729166,
#                                       'seasonality_prior_scale': 4.636790659822745},
#                                   {   'changepoint_prior_scale': 0.0012831866225256955,
#                                       'seasonality_prior_scale': 2.8472193174435665},
#                                   {   'changepoint_prior_scale': 0.0017832987777073905,
#                                       'seasonality_prior_scale': 1.0609475905750005},
#                                   {   'changepoint_prior_scale': 0.00124144592431223,
#                                       'seasonality_prior_scale': 6.978922341121136},
#                                   {   'changepoint_prior_scale': 0.007063330690051696,
#                                       'seasonality_prior_scale': 8.421502782555734},
#                                   {   'changepoint_prior_scale': 0.0024588352794511323,
#                                       'seasonality_prior_scale': 5.548400764550256},
#                                   {   'changepoint_prior_scale': 0.008426330906738787,
#                                       'seasonality_prior_scale': 7.922071275475922},
#                                   {   'changepoint_prior_scale': 0.002142030524176158,
#                                       'seasonality_prior_scale': 6.491085366338613},
#                                   {   'changepoint_prior_scale': 0.0011737571956328093,
#                                       'seasonality_prior_scale': 9.349205818232578},
#                                   {   'changepoint_prior_scale': 0.0023940636626043027,
#                                       'seasonality_prior_scale': 7.4525237849081005},
#                                   {   'changepoint_prior_scale': 0.008046961576956385,
#                                       'seasonality_prior_scale': 8.87444614263966},
#                                   {   'changepoint_prior_scale': 0.009822601270607,
#                                       'seasonality_prior_scale': 6.0229155742845055},
#                                   {   'changepoint_prior_scale': 0.002182914199694715,
#                                       'seasonality_prior_scale': 9.790972673488188},
#                                   {   'changepoint_prior_scale': 0.005749808550887419,
#                                       'seasonality_prior_scale': 5.1179434774422},
#                                   {   'changepoint_prior_scale': 0.009869476498820563,
#                                       'seasonality_prior_scale': 0.2774146212317259}],
#     'objective_values': [   -10.004180798868088,
#                             -10.024311710980166,
#                             -10.023008713906927,
#                             -10.04998677853578,
#                             -10.61235085924873,
#                             -9.989444194614508,
#                             -10.578979825453429,
#                             -10.005272640166872,
#                             -9.984134991879408,
#                             -10.600586837427995,
#                             -10.018353060159498,
#                             -10.057670529373338,
#                             -10.039830650777354,
#                             -9.987123793140091,
#                             -10.060052411322319,
#                             -10.048681320617408,
#                             -10.022639588622562,
#                             -10.0559065015137,
#                             -10.033886785323125,
#                             -10.626440068823026,
#                             -9.992158871422243,
#                             -10.058950357746262,
#                             -10.56380944098351,
#                             -10.055476087281116,
#                             -10.591074396894108,
#                             -9.995743568410472,
#                             -9.995074568993454,
#                             -10.619804905316215,
#                             -10.198203612785795,
#                             -10.626335061032249,
#                             -10.028951299718962,
#                             -10.007704354874816,
#                             -10.050899272710588,
#                             -10.05761514158361,
#                             -10.576583029769418,
#                             -10.001237556893598,
#                             -10.051477938362114,
#                             -10.06561696133024,
#                             -10.041119311146646,
#                             -10.01537539519268,
#                             -10.072760745435106],
#     'random_hyper_parameters': [   {   'changepoint_prior_scale': 0.005649591062579136,
#                                        'seasonality_prior_scale': 5.307351287160325}],
#     'random_hyper_parameters_objective': [-10.004180798868088]}

# %% [markdown]
# #  See the learned classifier result on the test data

# %%
from classifiers.prophet import Prophet
from classifiers.xgboosttree import Xgboosttree
model = Xgboosttree()

import os
data_path = os.path.abspath('.')+'/classifiers/data/'

X_train, y_train =model.load_train_dataset(data_path+"PJME/train_data")
X_test, y_test = model.load_train_dataset(data_path+"PJME/test_data")
X_validate, y_validate = model.load_train_dataset(data_path+"PJME/validate_data")



model = Prophet(**results['best_hyper_parameter'])
model.fit(X_train, y_train.ravel())
y_pred = model.predict(X_test)

# %%
from matplotlib import pyplot as plt
fig = plt.figure(figsize=(30,10))
plt.rcParams.update({'font.size': 18})
plt.plot(X_test,y_test,label='Test')
plt.plot(X_test,y_pred,label='Prediction')
plt.title('Testing  Data')
plt.legend()
plt.show()

# %% [markdown]
# # All the Data

# %%
from classifiers.xgboosttree import Xgboosttree

model = Xgboosttree()

import os
data_path = os.path.abspath('.')+'/classifiers/data/'

X_train, y_train =model.load_train_dataset(data_path+"PJME/train_data")
X_test, y_test = model.load_train_dataset(data_path+"PJME/test_data")
X_validate, y_validate = model.load_train_dataset(data_path+"PJME/validate_data")



from matplotlib import pyplot as plt
fig = plt.figure(figsize=(30,10))
plt.rcParams.update({'font.size': 18})
plt.plot(X_train,y_train,label='Train')
plt.plot(X_validate,y_validate,label='validate')
plt.plot(X_test,y_test,label='Test')
plt.title('All  Data')
plt.legend()
plt.show()
