# %% [markdown]
# # An example tuning the hyperparameters of KNN classifier is shown as usecase.

# %%
from mango.tuner import Tuner

# %%
from scipy.stats import uniform


param_dict = {"n_neighbors": range(1, 50),
              'algorithm' : ['auto', 'ball_tree', 'kd_tree', 'brute']
             }

# %% [markdown]
# # userObjective

# %%
from sklearn import datasets
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_score


X, Y = datasets.load_breast_cancer(return_X_y=True)

def objectiveKNN(args_list):
    global X,Y
    
    results = []
    for hyper_par in args_list:
        clf = KNeighborsClassifier(**hyper_par)
        result  = cross_val_score(clf, X, Y, scoring='accuracy').mean()
        results.append(result)
    return results

# %%
conf_Dict = dict()
conf_Dict['batch_size'] = 5
conf_Dict['num_iteration'] = 5

# %% [markdown]
# # Defining Tuner

# %%
tuner_user = Tuner(param_dict, objectiveKNN, conf_Dict)

# %%
tuner_user.getConf()
# Out:
# {'param_dict': {'n_neighbors': range(1, 50),
#   'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute']},
#  'userObjective': <function __main__.objectiveKNN(args_list)>,
#  'domain_size': 5000,
#  'initial_random': 1,
#  'num_iteration': 5,
#  'objective': 'maximize',
#  'batch_size': 5}

# %%
results = tuner_user.maximize()

# %% [markdown]
# # Inspect the results

# %%
print('best parameters:',results['best_params'])
print('best accuracy:',results['best_objective'])
# Out:
# best parameters: {'algorithm': 'auto', 'n_neighbors': 11}
# best accuracy: 0.931486122714193

# %%
print('Sample parameters tried:',len(results['params_tried']))
print(results['params_tried'][:2])
# Out:
# Sample parameters tried: 26
# [{'n_neighbors': 26, 'algorithm': 'kd_tree'}, {'algorithm': 'auto', 'n_neighbors': 1}]

# %%
print('Sample objective values',len(results['objective_values']))
print(results['objective_values'][:5])
# Out:
# Sample objective values 26
# [0.9104242086698227, 0.9050960735171261, 0.9157059314954052, 0.9156873665645596, 0.9208855472013368]

# %% [markdown]
# # Plotting the variation in objective values of the tried results

# %%
Size = 201 

from matplotlib import pyplot as plt
fig = plt.figure(figsize=(30,5))
plt.title('Variation of Objective',fontsize=20)
plt.plot(results['objective_values'][:Size],lw=4,label='BL')
plt.xlabel('Configuration', fontsize=25)
plt.ylabel('objective_values',fontsize=25)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.legend(prop={'size': 30})
plt.show()

# %% [markdown]
# # Plotting the variation of Max objective values of the tried results

# %%
Size = 30 

import numpy as np

results_obj = np.array(results['objective_values'])

y_max=[]
for i in range(results_obj.shape[0]):
    y_max.append(np.max(results_obj[:i+1]))

from matplotlib import pyplot as plt
fig = plt.figure(figsize=(30,5))
plt.title('Max variation of Objective',fontsize=20)
plt.plot(y_max[:Size],lw=4,label='BL')
plt.xlabel('Configurations', fontsize=25)
plt.ylabel('objective_values',fontsize=25)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.legend(prop={'size': 30})
plt.show()

# %% [markdown]
# # See the Result

# %%
import pprint
pp = pprint.PrettyPrinter(indent=4)
pp.pprint(results)
# Out:
# {   'best_objective': 0.931486122714193,
#     'best_params': {'algorithm': 'auto', 'n_neighbors': 11},
#     'objective_values': [   0.9104242086698227,
#                             0.9050960735171261,
#                             0.9157059314954052,
#                             0.9156873665645596,
#                             0.9208855472013368,
#                             0.9208855472013368,
#                             0.9086512577740647,
#                             0.9086512577740647,
#                             0.9086512577740647,
#                             0.9086512577740647,
#                             0.9086512577740647,
#                             0.9297131718184349,
#                             0.9314768402487701,
#                             0.931486122714193,
#                             0.9297224542838577,
#                             0.9297131718184349,
#                             0.9244592963891209,
#                             0.931486122714193,
#                             0.9297224542838577,
#                             0.931486122714193,
#                             0.9297224542838577,
#                             0.9139422630650701,
#                             0.9104334911352455,
#                             0.9050960735171261,
#                             0.9139515455304928,
#                             0.9139515455304928],
#     'params_tried': [   {'algorithm': 'kd_tree', 'n_neighbors': 26},
#                         {'algorithm': 'auto', 'n_neighbors': 1},
#                         {'algorithm': 'auto', 'n_neighbors': 36},
#                         {'algorithm': 'kd_tree', 'n_neighbors': 21},
#                         {'algorithm': 'kd_tree', 'n_neighbors': 4},
#                         {'algorithm': 'kd_tree', 'n_neighbors': 4},
#                         {'algorithm': 'kd_tree', 'n_neighbors': 49},
#                         {'algorithm': 'ball_tree', 'n_neighbors': 49},
#                         {'algorithm': 'brute', 'n_neighbors': 49},
#                         {'algorithm': 'auto', 'n_neighbors': 49},
#                         {'algorithm': 'brute', 'n_neighbors': 49},
#                         {'algorithm': 'ball_tree', 'n_neighbors': 10},
#                         {'algorithm': 'brute', 'n_neighbors': 9},
#                         {'algorithm': 'auto', 'n_neighbors': 11},
#                         {'algorithm': 'kd_tree', 'n_neighbors': 12},
#                         {'algorithm': 'kd_tree', 'n_neighbors': 10},
#                         {'algorithm': 'brute', 'n_neighbors': 15},
#                         {'algorithm': 'brute', 'n_neighbors': 11},
#                         {'algorithm': 'brute', 'n_neighbors': 12},
#                         {'algorithm': 'brute', 'n_neighbors': 11},
#                         {'algorithm': 'brute', 'n_neighbors': 12},
#                         {'algorithm': 'kd_tree', 'n_neighbors': 43},
#                         {'algorithm': 'ball_tree', 'n_neighbors': 32},
#                         {'algorithm': 'brute', 'n_neighbors': 1},
#                         {'algorithm': 'auto', 'n_neighbors': 25},
#                         {'algorithm': 'brute', 'n_neighbors': 37}],
#     'random_params': [{'algorithm': 'kd_tree', 'n_neighbors': 26}],
#     'random_params_objective': [0.9104242086698227]}
