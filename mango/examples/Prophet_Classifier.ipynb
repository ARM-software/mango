# %% [markdown]
# # A sample example to tuning the hyperparameters of Prophet classifier is shown as usecase.

# %%
from mango.tuner import Tuner

# %%
from mango.domain.distribution import loguniform

param_dict = {"changepoint_prior_scale": loguniform(-3, 4),
              'seasonality_prior_scale' : loguniform(1, 2)
             }

# %% [markdown]
# # userObjective

# %%
from classifiers.prophet import Prophet
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_score
import numpy as np

model = Prophet()

import os
data_path = os.path.abspath('.')+'/classifiers/data/'

X_train, y_train =model.load_train_dataset(data_path+"PJME/train_data")
X_test, y_test = model.load_train_dataset(data_path+"PJME/test_data")
X_validate, y_validate = model.load_train_dataset(data_path+"PJME/validate_data")


count_called = 1

def objective_Prophet(args_list):
    global X_train, y_train,X_validate,y_validate, count_called
    
    print('count_called:',count_called)
    
    count_called = count_called + 1
    results = []
    for hyper_par in args_list:
        clf = Prophet(**hyper_par)
        clf.fit(X_train, y_train.ravel())
        y_pred = clf.predict(X_validate) 
        mse = mean_squared_error(y_validate, y_pred)
        mse = mse/10e5
        result =  (-1.0) * mse
        results.append(result)
    return results

# %%
conf_Dict = dict()
conf_Dict['batch_size'] = 1
conf_Dict['num_iteration'] = 10
#conf_Dict['domain_size'] = 10000

# %% [markdown]
# # Defining Tuner

# %%
tuner_user = Tuner(param_dict, objective_Prophet,conf_Dict)

# %%
tuner_user.getConf()
# Out:
# {'param_dict': {'changepoint_prior_scale': <scipy.stats._distn_infrastructure.rv_frozen at 0x1a146b4550>,
#   'seasonality_prior_scale': <scipy.stats._distn_infrastructure.rv_frozen at 0x1a146b4978>},
#  'userObjective': <function __main__.objective_Prophet(args_list)>,
#  'domain_size': 20000,
#  'initial_random': 1,
#  'num_iteration': 10,
#  'objective': 'maximize',
#  'batch_size': 1}

# %%
import time
start_time = time.clock()

results = tuner_user.maximize()

end_time = time.clock()


print(end_time - start_time)
# Out:
# count_called: 1
# count_called: 2
# count_called: 3
# count_called: 4
# count_called: 5
# count_called: 6
# count_called: 7
# count_called: 8
# count_called: 9
# count_called: 10
# count_called: 11
# 131.3921

# %% [markdown]
# # Inspect the results

# %%
print('best hyper parameters:',results['best_params'])
print('best objective:',results['best_objective'])
# Out:
# best hyper parameters: {'changepoint_prior_scale': 0.0032935660474137252, 'seasonality_prior_scale': 668.5769146215783}
# best objective: -9.983330407175597

# %%
print('Sample hyper parameters tried:',len(results['params_tried']))
print(results['params_tried'][:2])
# Out:
# Sample hyper parameters tried: 11
# [{'changepoint_prior_scale': 0.026307871208077323, 'seasonality_prior_scale': 27.711335284380382}, {'changepoint_prior_scale': 0.20547028543955106, 'seasonality_prior_scale': 444.47617947640396}]

# %%
print('Sample objective values',len(results['objective_values']))
print(results['objective_values'][:5])
# Out:
# Sample objective values 11
# [-10.480665832234948, -15.176035502502247, -16.37850004130551, -10.008789708960135, -16.965217612710905]

# %% [markdown]
# # Plotting the actual variation in objective values of the tried results

# %%
Size = 201 

from matplotlib import pyplot as plt
fig = plt.figure(figsize=(30,5))
plt.title('Variation of Objective',fontsize=20)
plt.plot(results['objective_values'][:Size],lw=4,label='BL')
plt.xlabel('Iterations', fontsize=25)
plt.ylabel('objective_values',fontsize=25)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.legend(prop={'size': 30})
plt.show()

# %% [markdown]
# # Plotting the variation of Max objective values of the tried results

# %%
Size = 201 

import numpy as np

results_obj = np.array(results['objective_values'])

y_max=[]
for i in range(results_obj.shape[0]):
    y_max.append(np.max(results_obj[:i+1]))

from matplotlib import pyplot as plt
fig = plt.figure(figsize=(30,5))
plt.title('Max variation of Objective',fontsize=20)
plt.plot(y_max[:Size],lw=4,label='BL')
plt.xlabel('Iterations', fontsize=25)
plt.ylabel('objective_values',fontsize=25)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.legend(prop={'size': 30})
plt.show()

# %% [markdown]
# # See the Result

# %%
import pprint
pp = pprint.PrettyPrinter(indent=4)
pp.pprint(results)
# Out:
# {   'best_objective': -9.983330407175597,
#     'best_params': {   'changepoint_prior_scale': 0.0032935660474137252,
#                        'seasonality_prior_scale': 668.5769146215783},
#     'objective_values': [   -10.480665832234948,
#                             -15.176035502502247,
#                             -16.37850004130551,
#                             -10.008789708960135,
#                             -16.965217612710905,
#                             -12.08523018840899,
#                             -15.985507515338501,
#                             -9.983330407175597,
#                             -16.82979059239863,
#                             -10.062070498599084,
#                             -10.625023727730872],
#     'params_tried': [   {   'changepoint_prior_scale': 0.026307871208077323,
#                             'seasonality_prior_scale': 27.711335284380382},
#                         {   'changepoint_prior_scale': 0.20547028543955106,
#                             'seasonality_prior_scale': 444.47617947640396},
#                         {   'changepoint_prior_scale': 3.042223900251314,
#                             'seasonality_prior_scale': 19.583487159464333},
#                         {   'changepoint_prior_scale': 0.004759230088965166,
#                             'seasonality_prior_scale': 26.45507090829601},
#                         {   'changepoint_prior_scale': 9.161509022030216,
#                             'seasonality_prior_scale': 46.811395421970516},
#                         {   'changepoint_prior_scale': 0.03838169586766551,
#                             'seasonality_prior_scale': 690.423587215873},
#                         {   'changepoint_prior_scale': 1.5626854650167072,
#                             'seasonality_prior_scale': 711.8068426213981},
#                         {   'changepoint_prior_scale': 0.0032935660474137252,
#                             'seasonality_prior_scale': 668.5769146215783},
#                         {   'changepoint_prior_scale': 3.453366792625612,
#                             'seasonality_prior_scale': 648.9917019185538},
#                         {   'changepoint_prior_scale': 0.009460802535621272,
#                             'seasonality_prior_scale': 385.9848333434762},
#                         {   'changepoint_prior_scale': 0.02944190891266537,
#                             'seasonality_prior_scale': 406.1660682878925}],
#     'random_params': [   {   'changepoint_prior_scale': 0.026307871208077323,
#                              'seasonality_prior_scale': 27.711335284380382}],
#     'random_params_objective': [-10.480665832234948]}

# %% [markdown]
# #  See the learned classifier result on the test data

# %%
model = Prophet(**results['best_params'])
model.fit(X_train, y_train.ravel())
y_pred = model.predict(X_test)

# %%
from matplotlib import pyplot as plt
fig = plt.figure(figsize=(30,10))
plt.rcParams.update({'font.size': 18})
plt.plot(X_test,y_test,label='Test')
plt.plot(X_test,y_pred,label='Prediction')
plt.title('Testing  Data')
plt.legend()
plt.show()

# %% [markdown]
# # All the Data

# %%
from classifiers.prophet import Prophet

model = Prophet()

import os
data_path = os.path.abspath('.')+'/classifiers/data/'

X_train, y_train =model.load_train_dataset(data_path+"PJME/train_data")
X_test, y_test = model.load_train_dataset(data_path+"PJME/test_data")
X_validate, y_validate = model.load_train_dataset(data_path+"PJME/validate_data")



from matplotlib import pyplot as plt
fig = plt.figure(figsize=(30,10))
plt.rcParams.update({'font.size': 18})
plt.plot(X_train,y_train,label='Train')
plt.plot(X_validate,y_validate,label='validate')
plt.plot(X_test,y_test,label='Test')
plt.title('All  Data')
plt.legend()
plt.show()
