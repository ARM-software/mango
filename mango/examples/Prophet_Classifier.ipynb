# %% [markdown]
# # A sample example to tuning the hyperparameters of Prophet classifier is shown as usecase.

# %%
from mango.tuner import Tuner

# %%
from mango.domain.distribution import loguniform

param_dict = {"changepoint_prior_scale": loguniform(-3, 1),
              'seasonality_prior_scale' : loguniform(1, 2)
             }

# %% [markdown]
# # userObjective

# %%
from classifiers.prophet import Prophet
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_score
import numpy as np

model = Prophet()

import os
data_path = os.path.abspath('.')+'/classifiers/data/'

X_train, y_train =model.load_train_dataset(data_path+"PJME/train_data")
X_test, y_test = model.load_train_dataset(data_path+"PJME/test_data")
X_validate, y_validate = model.load_train_dataset(data_path+"PJME/validate_data")


count_called = 1

def objective_Prophet(args_list):
    global X_train, y_train,X_validate,y_validate, count_called
    
    print('count_called:',count_called)
    
    count_called = count_called + 1
    results = []
    for hyper_par in args_list:
        clf = Prophet(**hyper_par)
        clf.fit(X_train, y_train.ravel())
        y_pred = clf.predict(X_validate) 
        mse = mean_squared_error(y_validate, y_pred)
        mse = mse/10e5
        result =  (-1.0) * mse
        results.append(result)
    return results

# %%
conf_Dict = dict()
conf_Dict['batch_size'] = 1
conf_Dict['num_iteration'] = 40
conf_Dict['domain_size'] = 10000

# %% [markdown]
# # Defining Tuner

# %%
tuner_user = Tuner(param_dict, objective_Prophet,conf_Dict)

# %%
tuner_user.getConf()
# Out:
# {'param_dict': {'changepoint_prior_scale': <scipy.stats._distn_infrastructure.rv_frozen at 0x1a2082f1d0>,
#   'seasonality_prior_scale': <scipy.stats._distn_infrastructure.rv_frozen at 0x1a2082f5f8>},
#  'userObjective': <function __main__.objective_Prophet(args_list)>,
#  'domain_size': 10000,
#  'initial_random': 1,
#  'num_iteration': 40,
#  'objective': 'maximize',
#  'batch_size': 1}

# %%
import time
start_time = time.clock()

results = tuner_user.run()

end_time = time.clock()


print(end_time - start_time)
# Out:
# count_called: 1
# count_called: 2
# count_called: 3
# count_called: 4
# count_called: 5
# count_called: 6
# count_called: 7
# count_called: 8
# count_called: 9
# count_called: 10
# count_called: 11
# count_called: 12
# count_called: 13
# count_called: 14
# count_called: 15
# count_called: 16
# count_called: 17
# count_called: 18
# count_called: 19
# count_called: 20
# count_called: 21
# count_called: 22
# count_called: 23
# count_called: 24
# count_called: 25
# count_called: 26
# count_called: 27
# count_called: 28
# count_called: 29
# count_called: 30
# count_called: 31
# count_called: 32
# count_called: 33
# count_called: 34
# count_called: 35
# count_called: 36
# count_called: 37
# count_called: 38
# count_called: 39
# count_called: 40
# count_called: 41
# 418.45218800000004

# %% [markdown]
# # Inspect the results

# %%
print('best hyper parameters:',results['best_hyper_parameter'])
print('best objective:',results['best_objective'])
# Out:
# best hyper parameters: {'changepoint_prior_scale': 0.0035868496804799515, 'seasonality_prior_scale': 564.7883898164421}
# best objective: -9.97848683700179

# %%
print('Sample hyper parameters tried:',len(results['hyper_parameters_tried']))
print(results['hyper_parameters_tried'][:2])
# Out:
# Sample hyper parameters tried: 41
# [{'changepoint_prior_scale': 0.009550775310058535, 'seasonality_prior_scale': 132.21449512681022}, {'changepoint_prior_scale': 0.00712757902094477, 'seasonality_prior_scale': 404.4616737777648}]

# %%
print('Sample objective values',len(results['objective_values']))
print(results['objective_values'][:5])
# Out:
# Sample objective values 41
# [-10.069658921760942, -10.050759203409271, -10.603785854108803, -10.051283525833531, -10.037243950047587]

# %% [markdown]
# # Plotting the actual variation in objective values of the tried results

# %%
Size = 201 

from matplotlib import pyplot as plt
fig = plt.figure(figsize=(30,5))
plt.title('Variation of Objective',fontsize=20)
plt.plot(results['objective_values'][:Size],lw=4,label='BL')
plt.xlabel('Iterations', fontsize=25)
plt.ylabel('objective_values',fontsize=25)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.legend(prop={'size': 30})
plt.show()

# %% [markdown]
# # Plotting the variation of Max objective values of the tried results

# %%
Size = 201 

import numpy as np

results_obj = np.array(results['objective_values'])

y_max=[]
for i in range(results_obj.shape[0]):
    y_max.append(np.max(results_obj[:i+1]))

from matplotlib import pyplot as plt
fig = plt.figure(figsize=(30,5))
plt.title('Max variation of Objective',fontsize=20)
plt.plot(y_max[:Size],lw=4,label='BL')
plt.xlabel('Iterations', fontsize=25)
plt.ylabel('objective_values',fontsize=25)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.legend(prop={'size': 30})
plt.show()

# %% [markdown]
# # See the Result

# %%
import pprint
pp = pprint.PrettyPrinter(indent=4)
pp.pprint(results)
# Out:
# {   'best_hyper_parameter': {   'changepoint_prior_scale': 0.0035868496804799515,
#                                 'seasonality_prior_scale': 564.7883898164421},
#     'best_objective': -9.97848683700179,
#     'hyper_parameters_tried': [   {   'changepoint_prior_scale': 0.009550775310058535,
#                                       'seasonality_prior_scale': 132.21449512681022},
#                                   {   'changepoint_prior_scale': 0.00712757902094477,
#                                       'seasonality_prior_scale': 404.4616737777648},
#                                   {   'changepoint_prior_scale': 0.0014271460845660367,
#                                       'seasonality_prior_scale': 999.9823673654116},
#                                   {   'changepoint_prior_scale': 0.00968341913569553,
#                                       'seasonality_prior_scale': 708.319249329914},
#                                   {   'changepoint_prior_scale': 0.0019707340654933807,
#                                       'seasonality_prior_scale': 10.010404376299466},
#                                   {   'changepoint_prior_scale': 0.0035868496804799515,
#                                       'seasonality_prior_scale': 564.7883898164421},
#                                   {   'changepoint_prior_scale': 0.0017952844085983607,
#                                       'seasonality_prior_scale': 618.0741635488778},
#                                   {   'changepoint_prior_scale': 0.008305338931293219,
#                                       'seasonality_prior_scale': 869.9409596876884},
#                                   {   'changepoint_prior_scale': 0.00100138086899213,
#                                       'seasonality_prior_scale': 267.81567422003036},
#                                   {   'changepoint_prior_scale': 0.001393840496570827,
#                                       'seasonality_prior_scale': 793.5286085747609},
#                                   {   'changepoint_prior_scale': 0.0014572691602930345,
#                                       'seasonality_prior_scale': 479.8225254733335},
#                                   {   'changepoint_prior_scale': 0.007212995499214487,
#                                       'seasonality_prior_scale': 574.5942013591574},
#                                   {   'changepoint_prior_scale': 0.009331078117761972,
#                                       'seasonality_prior_scale': 554.8380818515401},
#                                   {   'changepoint_prior_scale': 0.006001736315302643,
#                                       'seasonality_prior_scale': 19.886320591627904},
#                                   {   'changepoint_prior_scale': 0.003413475592218448,
#                                       'seasonality_prior_scale': 29.819004166416583},
#                                   {   'changepoint_prior_scale': 0.005201733557863753,
#                                       'seasonality_prior_scale': 39.70211343343086},
#                                   {   'changepoint_prior_scale': 0.002800837822384571,
#                                       'seasonality_prior_scale': 49.58295504199647},
#                                   {   'changepoint_prior_scale': 0.0026380732002483608,
#                                       'seasonality_prior_scale': 59.58755529521846},
#                                   {   'changepoint_prior_scale': 0.008595274336846887,
#                                       'seasonality_prior_scale': 69.5954462426537},
#                                   {   'changepoint_prior_scale': 0.0038040105237377893,
#                                       'seasonality_prior_scale': 584.8821798367211},
#                                   {   'changepoint_prior_scale': 0.004640218397207567,
#                                       'seasonality_prior_scale': 594.743020618832},
#                                   {   'changepoint_prior_scale': 0.006218889829515371,
#                                       'seasonality_prior_scale': 604.8833343428424},
#                                   {   'changepoint_prior_scale': 0.0010417732372029244,
#                                       'seasonality_prior_scale': 79.86786721097903},
#                                   {   'changepoint_prior_scale': 0.008020694073969778,
#                                       'seasonality_prior_scale': 394.1927640328338},
#                                   {   'changepoint_prior_scale': 0.002653324533509032,
#                                       'seasonality_prior_scale': 383.9015031461682},
#                                   {   'changepoint_prior_scale': 0.001845565900921324,
#                                       'seasonality_prior_scale': 373.80142225182186},
#                                   {   'changepoint_prior_scale': 0.009411143914522078,
#                                       'seasonality_prior_scale': 880.1219588675732},
#                                   {   'changepoint_prior_scale': 0.0034461214419129658,
#                                       'seasonality_prior_scale': 859.6569077687891},
#                                   {   'changepoint_prior_scale': 0.004557728255062302,
#                                       'seasonality_prior_scale': 849.8406990263248},
#                                   {   'changepoint_prior_scale': 0.002400586679735938,
#                                       'seasonality_prior_scale': 839.8660736764638},
#                                   {   'changepoint_prior_scale': 0.00145997617356766,
#                                       'seasonality_prior_scale': 829.4990431159221},
#                                   {   'changepoint_prior_scale': 0.0014061838142064487,
#                                       'seasonality_prior_scale': 719.1306015877985},
#                                   {   'changepoint_prior_scale': 0.004609193943033674,
#                                       'seasonality_prior_scale': 697.9765182035931},
#                                   {   'changepoint_prior_scale': 0.002607237629834867,
#                                       'seasonality_prior_scale': 687.8192388411852},
#                                   {   'changepoint_prior_scale': 0.0010164461822514935,
#                                       'seasonality_prior_scale': 890.4824500273944},
#                                   {   'changepoint_prior_scale': 0.00816313185031973,
#                                       'seasonality_prior_scale': 677.8082247662414},
#                                   {   'changepoint_prior_scale': 0.005989577511616907,
#                                       'seasonality_prior_scale': 667.4255863979907},
#                                   {   'changepoint_prior_scale': 0.0010753812573250335,
#                                       'seasonality_prior_scale': 657.3919905777464},
#                                   {   'changepoint_prior_scale': 0.0017831730037205147,
#                                       'seasonality_prior_scale': 544.5875856103655},
#                                   {   'changepoint_prior_scale': 0.006954255138814301,
#                                       'seasonality_prior_scale': 414.72855678690905},
#                                   {   'changepoint_prior_scale': 0.0010675668073503834,
#                                       'seasonality_prior_scale': 424.97682644147596}],
#     'objective_values': [   -10.069658921760942,
#                             -10.050759203409271,
#                             -10.603785854108803,
#                             -10.051283525833531,
#                             -10.037243950047587,
#                             -9.97848683700179,
#                             -10.133964241721914,
#                             -10.044319837703535,
#                             -10.541161353452704,
#                             -10.627656644171784,
#                             -10.621450560848873,
#                             -10.041019472655876,
#                             -10.069872288307414,
#                             -10.014721982853994,
#                             -9.978744906815297,
#                             -9.995352104126729,
#                             -9.984219090326324,
#                             -10.001911243553778,
#                             -10.048820646597875,
#                             -10.00037776530512,
#                             -9.9870579147321,
#                             -10.009645939787505,
#                             -10.751011423041698,
#                             -10.044586808326644,
#                             -9.987809007671668,
#                             -10.203836923985362,
#                             -10.038596508868142,
#                             -9.981673867627917,
#                             -9.991801928357178,
#                             -10.007665151012569,
#                             -10.28797429548217,
#                             -10.632221932503017,
#                             -9.995087012614789,
#                             -9.99695054213738,
#                             -10.491143056726795,
#                             -10.038762813057813,
#                             -10.021487025103086,
#                             -10.575433978421177,
#                             -10.12871608079662,
#                             -10.03319573261219,
#                             -10.618489015983835],
#     'random_hyper_parameters': [   {   'changepoint_prior_scale': 0.009550775310058535,
#                                        'seasonality_prior_scale': 132.21449512681022}],
#     'random_hyper_parameters_objective': [-10.069658921760942]}

# %% [markdown]
# #  See the learned classifier result on the test data

# %%
model = Prophet(**results['best_hyper_parameter'])
model.fit(X_train, y_train.ravel())
y_pred = model.predict(X_test)

# %%
from matplotlib import pyplot as plt
fig = plt.figure(figsize=(30,10))
plt.rcParams.update({'font.size': 18})
plt.plot(X_test,y_test,label='Test')
plt.plot(X_test,y_pred,label='Prediction')
plt.title('Testing  Data')
plt.legend()
plt.show()

# %% [markdown]
# # All the Data

# %%
from classifiers.prophet import Prophet

model = Prophet()

import os
data_path = os.path.abspath('.')+'/classifiers/data/'

X_train, y_train =model.load_train_dataset(data_path+"PJME/train_data")
X_test, y_test = model.load_train_dataset(data_path+"PJME/test_data")
X_validate, y_validate = model.load_train_dataset(data_path+"PJME/validate_data")



from matplotlib import pyplot as plt
fig = plt.figure(figsize=(30,10))
plt.rcParams.update({'font.size': 18})
plt.plot(X_train,y_train,label='Train')
plt.plot(X_validate,y_validate,label='validate')
plt.plot(X_test,y_test,label='Test')
plt.title('All  Data')
plt.legend()
plt.show()
