# %% [markdown]
# # Testing Mango

# %%
from mango.tuner import Tuner

# %%
from scipy.stats import uniform

param_dict = {"learning_rate": uniform(0.01, 0.5),
              "gamma": uniform(0.5, 0.5),
              "max_depth": range(1,14),
              "n_estimators": range(500,2000),
              "subsample": uniform(0.7, 0.3),
              "colsample_bytree":uniform(0.3, 0.7),
              "colsample_bylevel":uniform(0.3, 0.7),
              "min_child_weight": range(1,10)}

# %% [markdown]
# # userObjective

# %%
from classifiers.xgboosttree import Xgboosttree
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_score

import numpy as np

model = Xgboosttree()

import os
data_path = os.path.abspath('.')+'/classifiers/data/'

X_train, y_train =model.load_train_dataset(data_path+"PJME/train_data")
X_test, y_test = model.load_train_dataset(data_path+"PJME/test_data")
X_validate, y_validate = model.load_train_dataset(data_path+"PJME/validate_data")




count_called = 1

def objective_Xgboost(args_list):
    global X_train, y_train, model, count_called
    
    print('count_called:',count_called)
    
    count_called = count_called + 1
    results = []
    for hyper_par in args_list:
        clf = Xgboosttree(**hyper_par)
        clf.fit(X_train, y_train.ravel())
        y_pred = clf.predict(X_validate) 
        mse = mean_squared_error(y_validate, y_pred)
        mse = mse/10e5
        result =  (-1.0) * mse
        results.append(result)
        
    return results

# %%
conf_Dict = dict()
conf_Dict['batch_size'] = 1
conf_Dict['num_iteration'] = 40
conf_Dict['domain_size'] = 10000

# %% [markdown]
# # Defining Tuner

# %%
tuner_user = Tuner(param_dict, objective_Xgboost,conf_Dict)

# %%
tuner_user.getConf()
# Out:
# {'param_dict': {'learning_rate': <scipy.stats._distn_infrastructure.rv_frozen at 0x1a1fc02828>,
#   'gamma': <scipy.stats._distn_infrastructure.rv_frozen at 0x1a1fc02d68>,
#   'max_depth': range(1, 14),
#   'n_estimators': range(500, 2000),
#   'subsample': <scipy.stats._distn_infrastructure.rv_frozen at 0x1a1fc02ef0>,
#   'colsample_bytree': <scipy.stats._distn_infrastructure.rv_frozen at 0x1a1fc02cc0>,
#   'colsample_bylevel': <scipy.stats._distn_infrastructure.rv_frozen at 0x1a1fc02e80>,
#   'min_child_weight': range(1, 10)},
#  'userObjective': <function __main__.objective_Xgboost(args_list)>,
#  'domain_size': 10000,
#  'initial_random': 1,
#  'num_iteration': 40,
#  'objective': 'maximize',
#  'batch_size': 1}

# %%
import time
start_time = time.clock()

results = tuner_user.run()

end_time = time.clock()


print(end_time - start_time)
# Out:
# count_called: 1
# [15:50:39] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# count_called: 2
# [15:51:02] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# count_called: 3
# [15:51:20] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# count_called: 4
# [15:51:48] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# count_called: 5
# [15:52:01] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# count_called: 6
# [15:52:14] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# count_called: 7
# [15:52:27] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# count_called: 8
# [15:52:37] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# count_called: 9
# [15:52:53] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# count_called: 10
# [15:53:03] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# count_called: 11
# [15:53:20] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# count_called: 12
# [15:53:41] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# count_called: 13
# [15:53:53] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# count_called: 14
# [15:53:59] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# count_called: 15
# [15:54:08] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# count_called: 16
# [15:54:17] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# count_called: 17
# [15:54:29] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# count_called: 18
# [15:54:42] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# count_called: 19
# [15:54:51] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# count_called: 20
# [15:54:58] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# count_called: 21
# [15:55:05] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# count_called: 22
# [15:55:14] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# count_called: 23
# [15:55:22] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# count_called: 24
# [15:55:31] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# count_called: 25
# [15:55:38] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# count_called: 26
# [15:55:43] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# count_called: 27
# [15:55:48] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# count_called: 28
# [15:55:53] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# count_called: 29
# [15:56:02] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# count_called: 30
# [15:56:18] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# count_called: 31
# [15:56:33] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# count_called: 32
# [15:56:37] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# count_called: 33
# [15:56:42] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# count_called: 34
# [15:56:54] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# count_called: 35
# [15:56:57] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# count_called: 36
# [15:57:01] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# count_called: 37
# [15:57:06] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# count_called: 38
# [15:57:10] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# count_called: 39
# [15:57:14] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# count_called: 40
# [15:57:18] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# count_called: 41
# [15:57:21] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 325.14275799999996

# %% [markdown]
# # Inspect the results

# %%
print('best hyper parameters:',results['best_hyper_parameter'])
print('best objective:',results['best_objective'])
# Out:
# best hyper parameters: {'colsample_bylevel': 0.4134594986186252, 'colsample_bytree': 0.7377021581060159, 'gamma': 0.8855206131064085, 'learning_rate': 0.2356585420277782, 'max_depth': 1, 'min_child_weight': 3, 'n_estimators': 833, 'subsample': 0.9455485219590243}
# best objective: -9.93627295394527

# %%
print('Sample hyper parameters tried:',len(results['hyper_parameters_tried']))
print(results['hyper_parameters_tried'][:2])
# Out:
# Sample hyper parameters tried: 41
# [{'colsample_bylevel': 0.5762811904188724, 'colsample_bytree': 0.9783286046755377, 'gamma': 0.908622115133723, 'learning_rate': 0.14362842230682277, 'max_depth': 10, 'min_child_weight': 3, 'n_estimators': 983, 'subsample': 0.9560248527972082}, {'colsample_bylevel': 0.6217333737272179, 'colsample_bytree': 0.45719954961923637, 'gamma': 0.5964417977802206, 'learning_rate': 0.3324452860327526, 'max_depth': 2, 'min_child_weight': 8, 'n_estimators': 1280, 'subsample': 0.8364970728806833}]

# %%
print('Sample objective values',len(results['objective_values']))
print(results['objective_values'][:5])
# Out:
# Sample objective values 41
# [-14.684781168108056, -12.091638010527722, -15.3356192415392, -11.868066698258671, -11.66076728641232]

# %% [markdown]
# # Plotting the actual variation in objective values of the tried results

# %%
Size = 201 

from matplotlib import pyplot as plt
fig = plt.figure(figsize=(30,5))
plt.title('Variation of Objective',fontsize=20)
plt.plot(results['objective_values'][:Size],lw=4,label='BL')
plt.xlabel('Iterations', fontsize=25)
plt.ylabel('objective_values',fontsize=25)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.legend(prop={'size': 30})
plt.show()

# %% [markdown]
# # Plotting the variation of Max objective values of the tried results

# %%
Size = 201 

import numpy as np

results_obj = np.array(results['objective_values'])

y_max=[]
for i in range(results_obj.shape[0]):
    y_max.append(np.max(results_obj[:i+1]))

from matplotlib import pyplot as plt
fig = plt.figure(figsize=(30,5))
plt.title('Max variation of Objective',fontsize=20)
plt.plot(y_max[:Size],lw=4,label='BL')
plt.xlabel('Iterations', fontsize=25)
plt.ylabel('objective_values',fontsize=25)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.legend(prop={'size': 30})
plt.show()

# %% [markdown]
# # See the Result

# %%
import pprint
pp = pprint.PrettyPrinter(indent=4)
pp.pprint(results)
# Out:
# {   'best_hyper_parameter': {   'colsample_bylevel': 0.4134594986186252,
#                                 'colsample_bytree': 0.7377021581060159,
#                                 'gamma': 0.8855206131064085,
#                                 'learning_rate': 0.2356585420277782,
#                                 'max_depth': 1,
#                                 'min_child_weight': 3,
#                                 'n_estimators': 833,
#                                 'subsample': 0.9455485219590243},
#     'best_objective': -9.93627295394527,
#     'hyper_parameters_tried': [   {   'colsample_bylevel': 0.5762811904188724,
#                                       'colsample_bytree': 0.9783286046755377,
#                                       'gamma': 0.908622115133723,
#                                       'learning_rate': 0.14362842230682277,
#                                       'max_depth': 10,
#                                       'min_child_weight': 3,
#                                       'n_estimators': 983,
#                                       'subsample': 0.9560248527972082},
#                                   {   'colsample_bylevel': 0.6217333737272179,
#                                       'colsample_bytree': 0.45719954961923637,
#                                       'gamma': 0.5964417977802206,
#                                       'learning_rate': 0.3324452860327526,
#                                       'max_depth': 2,
#                                       'min_child_weight': 8,
#                                       'n_estimators': 1280,
#                                       'subsample': 0.8364970728806833},
#                                   {   'colsample_bylevel': 0.6965649846329003,
#                                       'colsample_bytree': 0.6884811370111967,
#                                       'gamma': 0.746320498429421,
#                                       'learning_rate': 0.2243144178192618,
#                                       'max_depth': 10,
#                                       'min_child_weight': 7,
#                                       'n_estimators': 1276,
#                                       'subsample': 0.7960473107530854},
#                                   {   'colsample_bylevel': 0.6066370579455664,
#                                       'colsample_bytree': 0.4831743110050869,
#                                       'gamma': 0.6300120703545464,
#                                       'learning_rate': 0.0727768855209908,
#                                       'max_depth': 3,
#                                       'min_child_weight': 9,
#                                       'n_estimators': 1280,
#                                       'subsample': 0.7129841790348231},
#                                   {   'colsample_bylevel': 0.6314383112535256,
#                                       'colsample_bytree': 0.3607698428700115,
#                                       'gamma': 0.5649539009311673,
#                                       'learning_rate': 0.06479029169895399,
#                                       'max_depth': 4,
#                                       'min_child_weight': 9,
#                                       'n_estimators': 1309,
#                                       'subsample': 0.9113995466235462},
#                                   {   'colsample_bylevel': 0.7852209042966365,
#                                       'colsample_bytree': 0.3687818817393071,
#                                       'gamma': 0.9493877917842972,
#                                       'learning_rate': 0.03305030656428231,
#                                       'max_depth': 5,
#                                       'min_child_weight': 4,
#                                       'n_estimators': 1337,
#                                       'subsample': 0.774678857556542},
#                                   {   'colsample_bylevel': 0.9199335250483462,
#                                       'colsample_bytree': 0.9556055593466333,
#                                       'gamma': 0.8393048475952543,
#                                       'learning_rate': 0.44532503490534087,
#                                       'max_depth': 2,
#                                       'min_child_weight': 2,
#                                       'n_estimators': 1366,
#                                       'subsample': 0.701682785678054},
#                                   {   'colsample_bylevel': 0.4147197865800676,
#                                       'colsample_bytree': 0.9631405382218556,
#                                       'gamma': 0.576719106051542,
#                                       'learning_rate': 0.0281475447211818,
#                                       'max_depth': 6,
#                                       'min_child_weight': 6,
#                                       'n_estimators': 1510,
#                                       'subsample': 0.8001756959251911},
#                                   {   'colsample_bylevel': 0.4278523258035894,
#                                       'colsample_bytree': 0.3329253795099414,
#                                       'gamma': 0.8892627747787074,
#                                       'learning_rate': 0.3291243700014536,
#                                       'max_depth': 9,
#                                       'min_child_weight': 1,
#                                       'n_estimators': 625,
#                                       'subsample': 0.7802392902625415},
#                                   {   'colsample_bylevel': 0.3546462889794032,
#                                       'colsample_bytree': 0.32936865897421785,
#                                       'gamma': 0.5906012057934016,
#                                       'learning_rate': 0.4358963044806529,
#                                       'max_depth': 10,
#                                       'min_child_weight': 6,
#                                       'n_estimators': 1414,
#                                       'subsample': 0.9307833349185968},
#                                   {   'colsample_bylevel': 0.7987241898060828,
#                                       'colsample_bytree': 0.9388431214812831,
#                                       'gamma': 0.7218232083020584,
#                                       'learning_rate': 0.40471410246911443,
#                                       'max_depth': 13,
#                                       'min_child_weight': 5,
#                                       'n_estimators': 1542,
#                                       'subsample': 0.9110177042385259},
#                                   {   'colsample_bylevel': 0.9512165598911551,
#                                       'colsample_bytree': 0.6052329165341732,
#                                       'gamma': 0.5800235237645055,
#                                       'learning_rate': 0.409031565507662,
#                                       'max_depth': 11,
#                                       'min_child_weight': 3,
#                                       'n_estimators': 1478,
#                                       'subsample': 0.9759878473903291},
#                                   {   'colsample_bylevel': 0.9424425664915372,
#                                       'colsample_bytree': 0.37961645667841765,
#                                       'gamma': 0.7175672390621985,
#                                       'learning_rate': 0.12872693703839894,
#                                       'max_depth': 2,
#                                       'min_child_weight': 9,
#                                       'n_estimators': 1750,
#                                       'subsample': 0.9473996411754396},
#                                   {   'colsample_bylevel': 0.35153362642462993,
#                                       'colsample_bytree': 0.8342780115928805,
#                                       'gamma': 0.8437300828126949,
#                                       'learning_rate': 0.4121028288867795,
#                                       'max_depth': 9,
#                                       'min_child_weight': 2,
#                                       'n_estimators': 1722,
#                                       'subsample': 0.7200655363095239},
#                                   {   'colsample_bylevel': 0.7017068310956247,
#                                       'colsample_bytree': 0.37479495955863146,
#                                       'gamma': 0.8911829259668183,
#                                       'learning_rate': 0.441593754218133,
#                                       'max_depth': 6,
#                                       'min_child_weight': 4,
#                                       'n_estimators': 1780,
#                                       'subsample': 0.7861373939224485},
#                                   {   'colsample_bylevel': 0.3443741428204962,
#                                       'colsample_bytree': 0.6725065772821527,
#                                       'gamma': 0.8747735400875281,
#                                       'learning_rate': 0.2658061642638784,
#                                       'max_depth': 12,
#                                       'min_child_weight': 1,
#                                       'n_estimators': 1642,
#                                       'subsample': 0.9762119463701131},
#                                   {   'colsample_bylevel': 0.7469814094880112,
#                                       'colsample_bytree': 0.8220164686356439,
#                                       'gamma': 0.8849376731569748,
#                                       'learning_rate': 0.20937046386029284,
#                                       'max_depth': 12,
#                                       'min_child_weight': 6,
#                                       'n_estimators': 1077,
#                                       'subsample': 0.9709693518785928},
#                                   {   'colsample_bylevel': 0.7223765672077579,
#                                       'colsample_bytree': 0.4785389349396283,
#                                       'gamma': 0.5086234372542531,
#                                       'learning_rate': 0.3688328149403074,
#                                       'max_depth': 13,
#                                       'min_child_weight': 9,
#                                       'n_estimators': 868,
#                                       'subsample': 0.8235227743211899},
#                                   {   'colsample_bylevel': 0.7416398720644062,
#                                       'colsample_bytree': 0.8484460287785924,
#                                       'gamma': 0.6270843295995344,
#                                       'learning_rate': 0.30211892549999736,
#                                       'max_depth': 7,
#                                       'min_child_weight': 2,
#                                       'n_estimators': 680,
#                                       'subsample': 0.8947191426252484},
#                                   {   'colsample_bylevel': 0.8074769360958283,
#                                       'colsample_bytree': 0.629307350420634,
#                                       'gamma': 0.6946055041816965,
#                                       'learning_rate': 0.32949666853275245,
#                                       'max_depth': 2,
#                                       'min_child_weight': 8,
#                                       'n_estimators': 942,
#                                       'subsample': 0.9980633808103558},
#                                   {   'colsample_bylevel': 0.5331928907625183,
#                                       'colsample_bytree': 0.696341801446364,
#                                       'gamma': 0.6319504487552293,
#                                       'learning_rate': 0.054462167998004955,
#                                       'max_depth': 5,
#                                       'min_child_weight': 1,
#                                       'n_estimators': 910,
#                                       'subsample': 0.8610953503807313},
#                                   {   'colsample_bylevel': 0.5184622834235416,
#                                       'colsample_bytree': 0.8436897820126703,
#                                       'gamma': 0.656706960964436,
#                                       'learning_rate': 0.11303018364407451,
#                                       'max_depth': 3,
#                                       'min_child_weight': 7,
#                                       'n_estimators': 1188,
#                                       'subsample': 0.86264170692384},
#                                   {   'colsample_bylevel': 0.8170863763471425,
#                                       'colsample_bytree': 0.6757471693345718,
#                                       'gamma': 0.7885943355376278,
#                                       'learning_rate': 0.3086930471530115,
#                                       'max_depth': 6,
#                                       'min_child_weight': 8,
#                                       'n_estimators': 1221,
#                                       'subsample': 0.8508927119550291},
#                                   {   'colsample_bylevel': 0.7615885678568036,
#                                       'colsample_bytree': 0.7618673936268647,
#                                       'gamma': 0.6320392952067343,
#                                       'learning_rate': 0.020651185828634226,
#                                       'max_depth': 6,
#                                       'min_child_weight': 1,
#                                       'n_estimators': 1155,
#                                       'subsample': 0.9798748529939119},
#                                   {   'colsample_bylevel': 0.6541747680501724,
#                                       'colsample_bytree': 0.5747694716304381,
#                                       'gamma': 0.7114460774267269,
#                                       'learning_rate': 0.11847888320440707,
#                                       'max_depth': 3,
#                                       'min_child_weight': 7,
#                                       'n_estimators': 1025,
#                                       'subsample': 0.9503378098485797},
#                                   {   'colsample_bylevel': 0.5707572809551529,
#                                       'colsample_bytree': 0.594069765080958,
#                                       'gamma': 0.7754376151279598,
#                                       'learning_rate': 0.4053137886111065,
#                                       'max_depth': 9,
#                                       'min_child_weight': 9,
#                                       'n_estimators': 567,
#                                       'subsample': 0.8494902861338731},
#                                   {   'colsample_bylevel': 0.32649684699995707,
#                                       'colsample_bytree': 0.9102911274394545,
#                                       'gamma': 0.8344112554104403,
#                                       'learning_rate': 0.3715317871850288,
#                                       'max_depth': 10,
#                                       'min_child_weight': 2,
#                                       'n_estimators': 793,
#                                       'subsample': 0.7373092652269939},
#                                   {   'colsample_bylevel': 0.7458112326959795,
#                                       'colsample_bytree': 0.8859844827572696,
#                                       'gamma': 0.6668583595102688,
#                                       'learning_rate': 0.11535549520271564,
#                                       'max_depth': 3,
#                                       'min_child_weight': 8,
#                                       'n_estimators': 1958,
#                                       'subsample': 0.9695067962154956},
#                                   {   'colsample_bylevel': 0.7921478004536906,
#                                       'colsample_bytree': 0.7285244451815447,
#                                       'gamma': 0.9399480388063894,
#                                       'learning_rate': 0.4593342056799256,
#                                       'max_depth': 9,
#                                       'min_child_weight': 5,
#                                       'n_estimators': 1993,
#                                       'subsample': 0.7756351521674676},
#                                   {   'colsample_bylevel': 0.8318782781003147,
#                                       'colsample_bytree': 0.724980716607414,
#                                       'gamma': 0.6536153577910708,
#                                       'learning_rate': 0.2639626497045865,
#                                       'max_depth': 11,
#                                       'min_child_weight': 3,
#                                       'n_estimators': 1923,
#                                       'subsample': 0.7195346935554622},
#                                   {   'colsample_bylevel': 0.8340849735049545,
#                                       'colsample_bytree': 0.34597382991939624,
#                                       'gamma': 0.5005287336678079,
#                                       'learning_rate': 0.0224332921935732,
#                                       'max_depth': 2,
#                                       'min_child_weight': 3,
#                                       'n_estimators': 1850,
#                                       'subsample': 0.9954627848000142},
#                                   {   'colsample_bylevel': 0.47236825673361993,
#                                       'colsample_bytree': 0.9407146272946421,
#                                       'gamma': 0.5753685500383019,
#                                       'learning_rate': 0.21449585686164951,
#                                       'max_depth': 2,
#                                       'min_child_weight': 8,
#                                       'n_estimators': 1883,
#                                       'subsample': 0.7660004021277949},
#                                   {   'colsample_bylevel': 0.8868541100157583,
#                                       'colsample_bytree': 0.6454442087994408,
#                                       'gamma': 0.8682308831367112,
#                                       'learning_rate': 0.44121010099541,
#                                       'max_depth': 12,
#                                       'min_child_weight': 5,
#                                       'n_estimators': 1819,
#                                       'subsample': 0.7317243070053577},
#                                   {   'colsample_bylevel': 0.38883158343622704,
#                                       'colsample_bytree': 0.5749651778704825,
#                                       'gamma': 0.8185656606183673,
#                                       'learning_rate': 0.045991933190097915,
#                                       'max_depth': 4,
#                                       'min_child_weight': 1,
#                                       'n_estimators': 501,
#                                       'subsample': 0.7840185239544705},
#                                   {   'colsample_bylevel': 0.4873540274967569,
#                                       'colsample_bytree': 0.8365620539916894,
#                                       'gamma': 0.7220016293620349,
#                                       'learning_rate': 0.22614615676372707,
#                                       'max_depth': 12,
#                                       'min_child_weight': 3,
#                                       'n_estimators': 532,
#                                       'subsample': 0.7175505333288434},
#                                   {   'colsample_bylevel': 0.8559958492333155,
#                                       'colsample_bytree': 0.7359647560062639,
#                                       'gamma': 0.6788363887579958,
#                                       'learning_rate': 0.35856429728350564,
#                                       'max_depth': 8,
#                                       'min_child_weight': 3,
#                                       'n_estimators': 738,
#                                       'subsample': 0.7112833726339072},
#                                   {   'colsample_bylevel': 0.6693544304771541,
#                                       'colsample_bytree': 0.5366354405174378,
#                                       'gamma': 0.6753764482707082,
#                                       'learning_rate': 0.20796836444075,
#                                       'max_depth': 1,
#                                       'min_child_weight': 8,
#                                       'n_estimators': 1593,
#                                       'subsample': 0.8220699231171436},
#                                   {   'colsample_bylevel': 0.7134134048328926,
#                                       'colsample_bytree': 0.7737537391504816,
#                                       'gamma': 0.6778587564854739,
#                                       'learning_rate': 0.19051357830896187,
#                                       'max_depth': 1,
#                                       'min_child_weight': 2,
#                                       'n_estimators': 1680,
#                                       'subsample': 0.8138014277137822},
#                                   {   'colsample_bylevel': 0.4042988738897615,
#                                       'colsample_bytree': 0.3389835045870348,
#                                       'gamma': 0.7711085757194505,
#                                       'learning_rate': 0.35665360713047783,
#                                       'max_depth': 1,
#                                       'min_child_weight': 9,
#                                       'n_estimators': 1116,
#                                       'subsample': 0.9317307279622873},
#                                   {   'colsample_bylevel': 0.4134594986186252,
#                                       'colsample_bytree': 0.7377021581060159,
#                                       'gamma': 0.8855206131064085,
#                                       'learning_rate': 0.2356585420277782,
#                                       'max_depth': 1,
#                                       'min_child_weight': 3,
#                                       'n_estimators': 833,
#                                       'subsample': 0.9455485219590243},
#                                   {   'colsample_bylevel': 0.43786270668381017,
#                                       'colsample_bytree': 0.5739280856247094,
#                                       'gamma': 0.8022683161110948,
#                                       'learning_rate': 0.02443296936672045,
#                                       'max_depth': 2,
#                                       'min_child_weight': 9,
#                                       'n_estimators': 1447,
#                                       'subsample': 0.9196331630911843}],
#     'objective_values': [   -14.684781168108056,
#                             -12.091638010527722,
#                             -15.3356192415392,
#                             -11.868066698258671,
#                             -11.66076728641232,
#                             -12.097601504085779,
#                             -13.943242907944152,
#                             -13.581288751030543,
#                             -15.155029076640485,
#                             -16.990276876429576,
#                             -16.394496952202335,
#                             -15.295542600973986,
#                             -12.117119843051041,
#                             -17.487561512388403,
#                             -17.47198450869461,
#                             -15.787004852994386,
#                             -15.40740165615496,
#                             -15.57510562727254,
#                             -16.877608390420797,
#                             -11.946653859676665,
#                             -15.96254668109696,
#                             -12.75307218293839,
#                             -16.266164832541158,
#                             -17.842690388163053,
#                             -12.599026405147871,
#                             -15.661942962923579,
#                             -17.055322401645927,
#                             -13.647621292126619,
#                             -17.334504647870045,
#                             -15.628932364547339,
#                             -11.19765001764511,
#                             -12.19054736241463,
#                             -15.925848535932927,
#                             -11.147586348775873,
#                             -15.137874228169471,
#                             -16.880911498127897,
#                             -10.00119383194231,
#                             -9.937782721072756,
#                             -10.082391476317824,
#                             -9.93627295394527,
#                             -11.552783428067226],
#     'random_hyper_parameters': [   {   'colsample_bylevel': 0.5762811904188724,
#                                        'colsample_bytree': 0.9783286046755377,
#                                        'gamma': 0.908622115133723,
#                                        'learning_rate': 0.14362842230682277,
#                                        'max_depth': 10,
#                                        'min_child_weight': 3,
#                                        'n_estimators': 983,
#                                        'subsample': 0.9560248527972082}],
#     'random_hyper_parameters_objective': [-14.684781168108056]}

# %% [markdown]
# # See the learned classifier result on the test data

# %%
model = Xgboosttree(**results['best_hyper_parameter'])
model.fit(X_train, y_train.ravel())
y_pred = model.predict(X_test)
# Out:
# [15:57:23] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.

# %%
from matplotlib import pyplot as plt
fig = plt.figure(figsize=(30,10))
plt.rcParams.update({'font.size': 18})
plt.plot(X_test,y_test,label='Test')
plt.plot(X_test,y_pred,label='Prediction')
plt.title('Testing  Data')
plt.legend()
plt.show()

# %% [markdown]
# # All the Data

# %%
from classifiers.xgboosttree import Xgboosttree

model = Xgboosttree()

import os
data_path = os.path.abspath('.')+'/classifiers/data/'

X_train, y_train =model.load_train_dataset(data_path+"PJME/train_data")
X_test, y_test = model.load_train_dataset(data_path+"PJME/test_data")
X_validate, y_validate = model.load_train_dataset(data_path+"PJME/validate_data")




from matplotlib import pyplot as plt
fig = plt.figure(figsize=(30,10))
plt.rcParams.update({'font.size': 18})
plt.plot(X_train,y_train,label='Train')
plt.plot(X_validate,y_validate,label='validate')
plt.plot(X_test,y_test,label='Test')
plt.title('All  Data')
plt.legend()
plt.show()
