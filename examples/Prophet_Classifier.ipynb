# %% [markdown]
# # A sample example to tuning the hyperparameters of Prophet classifier is shown as usecase.

# %%
from mango.tuner import Tuner

# %%
from mango.domain.distribution import loguniform

param_dict = {"changepoint_prior_scale": loguniform(-3, 4),
              'seasonality_prior_scale' : loguniform(1, 2)
             }

# %% [markdown]
# # userObjective

# %%
from classifiers.prophet import Prophet
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_score
import numpy as np

model = Prophet()

import os
data_path = os.path.abspath('.')+'/classifiers/data/'

X_train, y_train =model.load_train_dataset(data_path+"PJME/train_data")
X_test, y_test = model.load_train_dataset(data_path+"PJME/test_data")
X_validate, y_validate = model.load_train_dataset(data_path+"PJME/validate_data")


count_called = 1

def objective_Prophet(args_list):
    global X_train, y_train,X_validate,y_validate, count_called
    
    print('count_called:',count_called)
    count_called = count_called + 1
    
    hyper_evaluated = []
    results = []
    for hyper_par in args_list:
        clf = Prophet(**hyper_par)
        clf.fit(X_train, y_train.ravel())
        y_pred = clf.predict(X_validate) 
        mse = mean_squared_error(y_validate, y_pred)
        mse = mse/10e5
        result =  (-1.0) * mse
        results.append(result)
        hyper_evaluated.append(hyper_par)
        
    return hyper_evaluated, results
# Out:
# ERROR:fbprophet:Importing plotly failed. Interactive plots will not work.

# %%
conf_Dict = dict()
conf_Dict['batch_size'] = 2
conf_Dict['num_iteration'] = 10
conf_Dict['initial_random'] = 5
#conf_Dict['domain_size'] = 10000

# %% [markdown]
# # Defining Tuner

# %%
tuner_user = Tuner(param_dict, objective_Prophet,conf_Dict)

# %%
tuner_user.getConf()
# Out:
# {'param_dict': {'changepoint_prior_scale': <scipy.stats._distn_infrastructure.rv_frozen at 0x121d23ef0>,
#   'seasonality_prior_scale': <scipy.stats._distn_infrastructure.rv_frozen at 0x121d33390>},
#  'userObjective': <function __main__.objective_Prophet(args_list)>,
#  'domain_size': 20000,
#  'initial_random': 5,
#  'num_iteration': 10,
#  'objective': 'maximize',
#  'batch_size': 2}

# %%
import time
start_time = time.clock()

results = tuner_user.maximize()

end_time = time.clock()


print(end_time - start_time)
# Out:
# count_called: 1
# count_called: 2
# count_called: 3
# count_called: 4
# count_called: 5
# count_called: 6
# count_called: 7
# count_called: 8
# count_called: 9
# count_called: 10
# count_called: 11
# 390.79589599999997

# %% [markdown]
# # Inspect the results

# %%
print('best hyper parameters:',results['best_params'])
print('best objective:',results['best_objective'])
# Out:
# best hyper parameters: {'changepoint_prior_scale': 0.0034796686441004735, 'seasonality_prior_scale': 28.590415978724305}
# best objective: -9.979760597905917

# %%
print('Sample hyper parameters tried:',len(results['params_tried']))
print(results['params_tried'][:2])
# Out:
# Sample hyper parameters tried: 25
# [{'changepoint_prior_scale': 0.4800895931934762, 'seasonality_prior_scale': 17.294224701838484}, {'changepoint_prior_scale': 0.25416212060493143, 'seasonality_prior_scale': 501.89540700062156}]

# %%
print('Sample objective values',len(results['objective_values']))
print(results['objective_values'][:5])
# Out:
# Sample objective values 25
# [-15.790523568024591, -15.449873168103066, -17.06900204855478, -12.74948441451744, -10.053214246489855]

# %% [markdown]
# # Plotting the actual variation in objective values of the tried results

# %%
Size = 201 

from matplotlib import pyplot as plt
fig = plt.figure(figsize=(30,5))
plt.title('Variation of Objective',fontsize=20)
plt.plot(results['objective_values'][:Size],lw=4,label='BL')
plt.xlabel('Iterations', fontsize=25)
plt.ylabel('objective_values',fontsize=25)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.legend(prop={'size': 30})
plt.show()

# %% [markdown]
# # Plotting the variation of Max objective values of the tried results

# %%
Size = 201 

import numpy as np

results_obj = np.array(results['objective_values'])

y_max=[]
for i in range(results_obj.shape[0]):
    y_max.append(np.max(results_obj[:i+1]))

from matplotlib import pyplot as plt
fig = plt.figure(figsize=(30,5))
plt.title('Max variation of Objective',fontsize=20)
plt.plot(y_max[:Size],lw=4,label='BL')
plt.xlabel('Iterations', fontsize=25)
plt.ylabel('objective_values',fontsize=25)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.legend(prop={'size': 30})
plt.show()

# %% [markdown]
# # See the Result

# %%
import pprint
pp = pprint.PrettyPrinter(indent=4)
pp.pprint(results)
# Out:
# {   'best_objective': -9.979760597905917,
#     'best_params': {   'changepoint_prior_scale': 0.0034796686441004735,
#                        'seasonality_prior_scale': 28.590415978724305},
#     'objective_values': [   -15.790523568024591,
#                             -15.449873168103066,
#                             -17.06900204855478,
#                             -12.74948441451744,
#                             -10.053214246489855,
#                             -12.951341960304761,
#                             -10.02620981670262,
#                             -16.581729776771443,
#                             -16.084031187548312,
#                             -14.478677229972313,
#                             -14.388547815436258,
#                             -16.579781135149325,
#                             -15.95255248265005,
#                             -10.218033626884688,
#                             -16.550142004163487,
#                             -10.15897552567475,
#                             -10.064868751228795,
#                             -10.028163059164585,
#                             -9.979760597905917,
#                             -11.49322342838692,
#                             -11.245856938119251,
#                             -16.18180611137518,
#                             -16.511199934542574,
#                             -10.029899817867104,
#                             -10.009756189808384],
#     'params_tried': [   {   'changepoint_prior_scale': 0.4800895931934762,
#                             'seasonality_prior_scale': 17.294224701838484},
#                         {   'changepoint_prior_scale': 0.25416212060493143,
#                             'seasonality_prior_scale': 501.89540700062156},
#                         {   'changepoint_prior_scale': 5.018424324129099,
#                             'seasonality_prior_scale': 434.7945875986463},
#                         {   'changepoint_prior_scale': 0.057576843869108184,
#                             'seasonality_prior_scale': 15.42524221614729},
#                         {   'changepoint_prior_scale': 0.0022656984653310597,
#                             'seasonality_prior_scale': 31.054460644781415},
#                         {   'changepoint_prior_scale': 0.05908954423770352,
#                             'seasonality_prior_scale': 70.08034743701644},
#                         {   'changepoint_prior_scale': 0.006394179018785245,
#                             'seasonality_prior_scale': 942.8140272734825},
#                         {   'changepoint_prior_scale': 3.97664728957574,
#                             'seasonality_prior_scale': 29.211046851705838},
#                         {   'changepoint_prior_scale': 1.7181863170787068,
#                             'seasonality_prior_scale': 26.295306457623752},
#                         {   'changepoint_prior_scale': 0.1380261516908404,
#                             'seasonality_prior_scale': 108.07926142979555},
#                         {   'changepoint_prior_scale': 0.11622237562772603,
#                             'seasonality_prior_scale': 359.41965745586816},
#                         {   'changepoint_prior_scale': 3.80449553789397,
#                             'seasonality_prior_scale': 15.940689211378587},
#                         {   'changepoint_prior_scale': 1.057177863746345,
#                             'seasonality_prior_scale': 15.33588734508675},
#                         {   'changepoint_prior_scale': 0.02115124263899764,
#                             'seasonality_prior_scale': 31.086394690366728},
#                         {   'changepoint_prior_scale': 3.694322814794867,
#                             'seasonality_prior_scale': 40.56836650703692},
#                         {   'changepoint_prior_scale': 0.0018090665962494001,
#                             'seasonality_prior_scale': 940.4374043336295},
#                         {   'changepoint_prior_scale': 0.011190098540234422,
#                             'seasonality_prior_scale': 945.2171880792673},
#                         {   'changepoint_prior_scale': 0.007836908097236868,
#                             'seasonality_prior_scale': 938.0947049363947},
#                         {   'changepoint_prior_scale': 0.0034796686441004735,
#                             'seasonality_prior_scale': 28.590415978724305},
#                         {   'changepoint_prior_scale': 0.028885011837210043,
#                             'seasonality_prior_scale': 947.767013455613},
#                         {   'changepoint_prior_scale': 0.02898682342217144,
#                             'seasonality_prior_scale': 935.4863371039424},
#                         {   'changepoint_prior_scale': 2.1235253348007714,
#                             'seasonality_prior_scale': 944.157540431685},
#                         {   'changepoint_prior_scale': 2.3744905299056147,
#                             'seasonality_prior_scale': 938.7110701688885},
#                         {   'changepoint_prior_scale': 0.002326984556483678,
#                             'seasonality_prior_scale': 932.9432242007595},
#                         {   'changepoint_prior_scale': 0.0021542939710382097,
#                             'seasonality_prior_scale': 950.2979030442898}],
#     'random_params': [   {   'changepoint_prior_scale': 0.4800895931934762,
#                              'seasonality_prior_scale': 17.294224701838484},
#                          {   'changepoint_prior_scale': 0.25416212060493143,
#                              'seasonality_prior_scale': 501.89540700062156},
#                          {   'changepoint_prior_scale': 5.018424324129099,
#                              'seasonality_prior_scale': 434.7945875986463},
#                          {   'changepoint_prior_scale': 0.057576843869108184,
#                              'seasonality_prior_scale': 15.42524221614729},
#                          {   'changepoint_prior_scale': 0.0022656984653310597,
#                              'seasonality_prior_scale': 31.054460644781415}],
#     'random_params_objective': [   -15.790523568024591,
#                                    -15.449873168103066,
#                                    -17.06900204855478,
#                                    -12.74948441451744,
#                                    -10.053214246489855]}

# %% [markdown]
# #  See the learned classifier result on the test data

# %%
model = Prophet(**results['best_params'])
model.fit(X_train, y_train.ravel())
y_pred = model.predict(X_test)

# %%
from matplotlib import pyplot as plt
fig = plt.figure(figsize=(30,10))
plt.rcParams.update({'font.size': 18})
plt.plot(X_test,y_test,label='Test')
plt.plot(X_test,y_pred,label='Prediction')
plt.title('Testing  Data')
plt.legend()
plt.show()

# %% [markdown]
# # All the Data

# %%
from classifiers.prophet import Prophet

model = Prophet()

import os
data_path = os.path.abspath('.')+'/classifiers/data/'

X_train, y_train =model.load_train_dataset(data_path+"PJME/train_data")
X_test, y_test = model.load_train_dataset(data_path+"PJME/test_data")
X_validate, y_validate = model.load_train_dataset(data_path+"PJME/validate_data")



from matplotlib import pyplot as plt
fig = plt.figure(figsize=(30,10))
plt.rcParams.update({'font.size': 18})
plt.plot(X_train,y_train,label='Train')
plt.plot(X_validate,y_validate,label='validate')
plt.plot(X_test,y_test,label='Test')
plt.title('All  Data')
plt.legend()
plt.show()
