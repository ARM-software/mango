# %% [markdown]
# # Testing the user defined function

# %%
import sys, os
sys.path.insert(0, os.path.abspath('..'))

# %%
from tuner import Tuner

# %%
from scipy.stats import uniform


param_dict = {"n_neighbors": range(1, 50),
              'algorithm' : ['auto', 'ball_tree', 'kd_tree', 'brute']
             }

# %% [markdown]
# # userObjective

# %%
from sklearn import datasets
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_score


X, Y = datasets.load_breast_cancer(return_X_y=True)

def objectiveKNN(args_list):
    global X,Y
    
    results = []
    for hyper_par in args_list:
        clf = KNeighborsClassifier(**hyper_par)
        result  = cross_val_score(clf, X, Y, scoring='accuracy').mean()
        results.append(result)
    return results

# %%
conf_Dict = dict()
conf_Dict['batch_size'] = 5
conf_Dict['num_iteration'] = 5

# %% [markdown]
# # Defining Tuner

# %%
tuner_user = Tuner(param_dict, objectiveKNN, conf_Dict)

# %%
tuner_user.getConf()
# Out:
# {'param_dict': {'n_neighbors': range(1, 50),
#   'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute']},
#  'userObjective': <function __main__.objectiveKNN(args_list)>,
#  'domain_size': 5000,
#  'initial_random': 1,
#  'num_iteration': 5,
#  'objective': 'maximize',
#  'batch_size': 5}

# %%
results = tuner_user.run()

# %% [markdown]
# # Inspect the results

# %%
print('best hyper parameters:',results['best_hyper_parameter'])
print('best objective:',results['best_objective'])
# Out:
# best hyper parameters: {'algorithm': 'auto', 'n_neighbors': 11}
# best objective: 0.931486122714193

# %%
print('Sample hyper parameters tried:',len(results['hyper_parameters_tried']))
print(results['hyper_parameters_tried'][:2])
# Out:
# Sample hyper parameters tried: 26
# [{'n_neighbors': 21, 'algorithm': 'ball_tree'}, {'algorithm': 'auto', 'n_neighbors': 1}]

# %%
print('Sample objective values',len(results['objective_values']))
print(results['objective_values'][:5])
# Out:
# Sample objective values 26
# [0.9156873665645596, 0.9050960735171261, 0.910405643738977, 0.9156873665645596, 0.9209041121321823]

# %% [markdown]
# # Plotting the variation in objective values of the tried results

# %%
Size = 201 

from matplotlib import pyplot as plt
fig = plt.figure(figsize=(30,5))
plt.title('Variation of Objective',fontsize=20)
plt.plot(results['objective_values'][:Size],lw=4,label='BL')
plt.xlabel('Iterations', fontsize=25)
plt.ylabel('objective_values',fontsize=25)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.legend(prop={'size': 30})
plt.show()

# %% [markdown]
# # Plotting the variation of Max objective values of the tried results

# %%
Size = 30 

import numpy as np

results_obj = np.array(results['objective_values'])

y_max=[]
for i in range(results_obj.shape[0]):
    y_max.append(np.max(results_obj[:i+1]))

from matplotlib import pyplot as plt
fig = plt.figure(figsize=(30,5))
plt.title('Max variation of Objective',fontsize=20)
plt.plot(y_max[:Size],lw=4,label='BL')
plt.xlabel('Configurations', fontsize=25)
plt.ylabel('objective_values',fontsize=25)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.legend(prop={'size': 30})
plt.show()

# %% [markdown]
# # See the Result

# %%
import pprint
pp = pprint.PrettyPrinter(indent=4)
pp.pprint(results)
# Out:
# {   'best_hyper_parameter': {'algorithm': 'auto', 'n_neighbors': 11},
#     'best_objective': 0.931486122714193,
#     'hyper_parameters_tried': [   {'algorithm': 'ball_tree', 'n_neighbors': 21},
#                                   {'algorithm': 'auto', 'n_neighbors': 1},
#                                   {'algorithm': 'kd_tree', 'n_neighbors': 48},
#                                   {'algorithm': 'brute', 'n_neighbors': 21},
#                                   {'algorithm': 'ball_tree', 'n_neighbors': 3},
#                                   {'algorithm': 'brute', 'n_neighbors': 38},
#                                   {'algorithm': 'ball_tree', 'n_neighbors': 49},
#                                   {'algorithm': 'kd_tree', 'n_neighbors': 1},
#                                   {'algorithm': 'brute', 'n_neighbors': 1},
#                                   {'algorithm': 'ball_tree', 'n_neighbors': 1},
#                                   {'algorithm': 'ball_tree', 'n_neighbors': 1},
#                                   {'algorithm': 'auto', 'n_neighbors': 44},
#                                   {'algorithm': 'kd_tree', 'n_neighbors': 12},
#                                   {'algorithm': 'auto', 'n_neighbors': 11},
#                                   {'algorithm': 'ball_tree', 'n_neighbors': 11},
#                                   {'algorithm': 'brute', 'n_neighbors': 9},
#                                   {'algorithm': 'brute', 'n_neighbors': 49},
#                                   {'algorithm': 'auto', 'n_neighbors': 31},
#                                   {'algorithm': 'kd_tree', 'n_neighbors': 8},
#                                   {'algorithm': 'ball_tree', 'n_neighbors': 8},
#                                   {'algorithm': 'ball_tree', 'n_neighbors': 8},
#                                   {'algorithm': 'auto', 'n_neighbors': 49},
#                                   {'algorithm': 'kd_tree', 'n_neighbors': 29},
#                                   {'algorithm': 'brute', 'n_neighbors': 15},
#                                   {'algorithm': 'ball_tree', 'n_neighbors': 34},
#                                   {'algorithm': 'kd_tree', 'n_neighbors': 38}],
#     'objective_values': [   0.9156873665645596,
#                             0.9050960735171261,
#                             0.910405643738977,
#                             0.9156873665645596,
#                             0.9209041121321823,
#                             0.9139422630650701,
#                             0.9086512577740647,
#                             0.9050960735171261,
#                             0.9050960735171261,
#                             0.9050960735171261,
#                             0.9050960735171261,
#                             0.9121693121693122,
#                             0.9297224542838577,
#                             0.931486122714193,
#                             0.931486122714193,
#                             0.9314768402487701,
#                             0.9086512577740647,
#                             0.9121878771001578,
#                             0.9261858349577649,
#                             0.9261858349577649,
#                             0.9261858349577649,
#                             0.9086512577740647,
#                             0.9121878771001578,
#                             0.9244592963891209,
#                             0.9121878771001578,
#                             0.9139422630650701],
#     'random_hyper_parameters': [{'algorithm': 'ball_tree', 'n_neighbors': 21}],
#     'random_hyper_parameters_objective': [0.9156873665645596]}
