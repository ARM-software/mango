# %% [markdown]
# # Celery is used to schedule the computation. A sample example to tuning the hyperparameters of Prophet classifier is shown as usecase.

# %%
from mango.tuner import Tuner

# %%
from mango.domain.distribution import loguniform

param_dict = {"changepoint_prior_scale": loguniform(-3, 1),
              'seasonality_prior_scale' : loguniform(-1, 2)
             }

# %% [markdown]
# # userObjective on Celery

# %%
from mango.examples.classifiers.CeleryTasks import run_prophet



iteration_count = 1

def objective_Prophet(args_list):
    global iteration_count
    
    print('iteration_count:',iteration_count)
    
    iteration_count = iteration_count+1
    process_queue =[]
    
    for hyper_par in args_list:
        process = run_prophet.delay(hyper_par)
        process_queue.append(process)
    
    results = []
    for process in process_queue:
        result = process.get(timeout=100)
        results.append(result)
           
    return results

# %%
conf_Dict = dict()
conf_Dict['batch_size'] = 4
conf_Dict['num_iteration'] = 5

# %% [markdown]
# # Defining Tuner

# %%
tuner_user = Tuner(param_dict, objective_Prophet,conf_Dict)

# %%
tuner_user.getConf()
# Out:
# {'param_dict': {'changepoint_prior_scale': <scipy.stats._distn_infrastructure.rv_frozen at 0x1a1703b3c8>,
#   'seasonality_prior_scale': <scipy.stats._distn_infrastructure.rv_frozen at 0x1a1703b7f0>},
#  'userObjective': <function __main__.objective_Prophet(args_list)>,
#  'domain_size': 5000,
#  'initial_random': 1,
#  'num_iteration': 5,
#  'objective': 'maximize',
#  'batch_size': 4}

# %%
results = tuner_user.maximize()
# Out:
# iteration_count: 1
# iteration_count: 2
# iteration_count: 3
# iteration_count: 4
# iteration_count: 5
# iteration_count: 6

# %% [markdown]
# # Inspect the results

# %%
print('best hyper parameters:',results['best_params'])
print('best objective:',results['best_objective'])
# Out:
# best hyper parameters: {'changepoint_prior_scale': 0.0042294922521082705, 'seasonality_prior_scale': 3.957068122364058}
# best objective: -9.98624125085345

# %%
print('Sample hyper parameters tried:',len(results['params_tried']))
print(results['params_tried'][:2])
# Out:
# Sample hyper parameters tried: 21
# [{'changepoint_prior_scale': 0.007171775499017729, 'seasonality_prior_scale': 0.6567066874502123}, {'changepoint_prior_scale': 0.007205258082367048, 'seasonality_prior_scale': 9.996656973924633}]

# %%
print('Sample objective values',len(results['objective_values']))
print(results['objective_values'][:5])
# Out:
# Sample objective values 21
# [-10.019531079190951, -10.024258744254709, -10.022958312583524, -10.020957323385364, -9.98624125085345]

# %% [markdown]
# # Plotting the actual variation in objective values of the tried results

# %%
Size = 201 

from matplotlib import pyplot as plt
fig = plt.figure(figsize=(30,5))
plt.title('Variation of Objective',fontsize=20)
plt.plot(results['objective_values'][:Size],lw=4,label='BL')
plt.xlabel('Configurations', fontsize=25)
plt.ylabel('objective_values',fontsize=25)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.legend(prop={'size': 30})
plt.show()

# %% [markdown]
# # Plotting the variation of Max objective values of the tried results

# %%
Size = 201 

import numpy as np

results_obj = np.array(results['objective_values'])

y_max=[]
for i in range(results_obj.shape[0]):
    y_max.append(np.max(results_obj[:i+1]))

from matplotlib import pyplot as plt
fig = plt.figure(figsize=(30,5))
plt.title('Max variation of Objective',fontsize=20)
plt.plot(y_max[:Size],lw=4,label='BL')
plt.xlabel('Configurations', fontsize=25)
plt.ylabel('objective_values',fontsize=25)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.legend(prop={'size': 30})
plt.show()

# %% [markdown]
# # See the Result

# %%
import pprint
pp = pprint.PrettyPrinter(indent=4)
pp.pprint(results)
# Out:
# {   'best_objective': -9.98624125085345,
#     'best_params': {   'changepoint_prior_scale': 0.0042294922521082705,
#                        'seasonality_prior_scale': 3.957068122364058},
#     'objective_values': [   -10.019531079190951,
#                             -10.024258744254709,
#                             -10.022958312583524,
#                             -10.020957323385364,
#                             -9.98624125085345,
#                             -10.578828346854804,
#                             -10.040424983212471,
#                             -10.7638129741824,
#                             -10.058406177114986,
#                             -9.993059432906612,
#                             -10.295900729131912,
#                             -10.000346635466068,
#                             -10.195629330143529,
#                             -10.560063286831268,
#                             -10.069513770186175,
#                             -10.59446574869579,
#                             -10.043457384730859,
#                             -9.99309690354698,
#                             -10.05699107097675,
#                             -10.593645924615922,
#                             -10.597769014986671],
#     'params_tried': [   {   'changepoint_prior_scale': 0.007171775499017729,
#                             'seasonality_prior_scale': 0.6567066874502123},
#                         {   'changepoint_prior_scale': 0.007205258082367048,
#                             'seasonality_prior_scale': 9.996656973924633},
#                         {   'changepoint_prior_scale': 0.00657595794621523,
#                             'seasonality_prior_scale': 5.251387622013974},
#                         {   'changepoint_prior_scale': 0.006716249074526715,
#                             'seasonality_prior_scale': 5.688470965983853},
#                         {   'changepoint_prior_scale': 0.0042294922521082705,
#                             'seasonality_prior_scale': 3.957068122364058},
#                         {   'changepoint_prior_scale': 0.0012884764330023842,
#                             'seasonality_prior_scale': 8.349066935601615},
#                         {   'changepoint_prior_scale': 0.009641754736083304,
#                             'seasonality_prior_scale': 2.059542484633663},
#                         {   'changepoint_prior_scale': 0.0010329247481434382,
#                             'seasonality_prior_scale': 2.850006943681849},
#                         {   'changepoint_prior_scale': 0.009652638402140402,
#                             'seasonality_prior_scale': 2.564146506724146},
#                         {   'changepoint_prior_scale': 0.004397122995482798,
#                             'seasonality_prior_scale': 7.044161876049919},
#                         {   'changepoint_prior_scale': 0.0018198253164321476,
#                             'seasonality_prior_scale': 9.171805538218344},
#                         {   'changepoint_prior_scale': 0.0026644110673572853,
#                             'seasonality_prior_scale': 0.10014811430358017},
#                         {   'changepoint_prior_scale': 0.001899965342786254,
#                             'seasonality_prior_scale': 1.3463651844581541},
#                         {   'changepoint_prior_scale': 0.0011704358310610477,
#                             'seasonality_prior_scale': 6.394853411637388},
#                         {   'changepoint_prior_scale': 0.009944911801978122,
#                             'seasonality_prior_scale': 7.703882956384562},
#                         {   'changepoint_prior_scale': 0.0011080451447297698,
#                             'seasonality_prior_scale': 4.579639159218607},
#                         {   'changepoint_prior_scale': 0.008497736698599526,
#                             'seasonality_prior_scale': 3.439255578041514},
#                         {   'changepoint_prior_scale': 0.005203834357876385,
#                             'seasonality_prior_scale': 9.590627998290088},
#                         {   'changepoint_prior_scale': 0.00829306335098738,
#                             'seasonality_prior_scale': 8.751857106222245},
#                         {   'changepoint_prior_scale': 0.0010663450030771343,
#                             'seasonality_prior_scale': 1.6923544992136688},
#                         {   'changepoint_prior_scale': 0.0012761259487647962,
#                             'seasonality_prior_scale': 6.0422974814062345}],
#     'random_params': [   {   'changepoint_prior_scale': 0.007171775499017729,
#                              'seasonality_prior_scale': 0.6567066874502123}],
#     'random_params_objective': [-10.019531079190951]}

# %% [markdown]
# #  See the learned classifier result on the test data

# %%
from classifiers.prophet import Prophet
from classifiers.xgboosttree import Xgboosttree
model = Xgboosttree()

import os
data_path = os.path.abspath('.')+'/classifiers/data/'

X_train, y_train =model.load_train_dataset(data_path+"PJME/train_data")
X_test, y_test = model.load_train_dataset(data_path+"PJME/test_data")
X_validate, y_validate = model.load_train_dataset(data_path+"PJME/validate_data")



model = Prophet(**results['best_params'])
model.fit(X_train, y_train.ravel())
y_pred = model.predict(X_test)

# %%
from matplotlib import pyplot as plt
fig = plt.figure(figsize=(30,10))
plt.rcParams.update({'font.size': 18})
plt.plot(X_test,y_test,label='Test')
plt.plot(X_test,y_pred,label='Prediction')
plt.title('Testing  Data')
plt.legend()
plt.show()

# %% [markdown]
# # All the Data

# %%
from classifiers.xgboosttree import Xgboosttree

model = Xgboosttree()

import os
data_path = os.path.abspath('.')+'/classifiers/data/'

X_train, y_train =model.load_train_dataset(data_path+"PJME/train_data")
X_test, y_test = model.load_train_dataset(data_path+"PJME/test_data")
X_validate, y_validate = model.load_train_dataset(data_path+"PJME/validate_data")



from matplotlib import pyplot as plt
fig = plt.figure(figsize=(30,10))
plt.rcParams.update({'font.size': 18})
plt.plot(X_train,y_train,label='Train')
plt.plot(X_validate,y_validate,label='validate')
plt.plot(X_test,y_test,label='Test')
plt.title('All  Data')
plt.legend()
plt.show()
