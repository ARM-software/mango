# %% [markdown]
# # An example tuning the hyperparameters of SVM classifier is shown as usecase.

# %%
from mango.tuner import Tuner

# %%
from scipy.stats import uniform
from mango.domain.distribution import loguniform

param_dict = {"gamma": uniform(0.1, 4),
              "C": loguniform(-7, 7)}

# %% [markdown]
# # userObjective

# %%
from sklearn import svm, datasets
from sklearn.model_selection import cross_val_score

iris = datasets.load_iris()

# Take only the first two features.
X = iris.data[:,:2]
Y = iris.target

def objectiveSVM(args_list):
    global X,Y
    
    results = []
    for hyper_par in args_list:
        clf = svm.SVC(**hyper_par)
        result  = cross_val_score(clf, X, Y, scoring='accuracy').mean()
        results.append(result)
    return results

# %%
conf_Dict = dict()
conf_Dict['batch_size'] = 3
conf_Dict['num_iteration'] = 20
conf_Dict['domain_size'] = 1000

# %% [markdown]
# # Defining Tuner

# %%
tuner_user = Tuner(param_dict, objectiveSVM, conf_Dict)

# %%
tuner_user.getConf()
# Out:
# {'param_dict': {'gamma': <scipy.stats._distn_infrastructure.rv_frozen at 0x111985a10>,
#   'C': <scipy.stats._distn_infrastructure.rv_frozen at 0x1213bde10>},
#  'userObjective': <function __main__.objectiveSVM(args_list)>,
#  'domain_size': 1000,
#  'initial_random': 1,
#  'num_iteration': 20,
#  'objective': 'maximize',
#  'batch_size': 3,
#  'optimizer': 'Bayesian'}

# %%
results = tuner_user.maximize()

# %% [markdown]
# # Inspect the results

# %%
print('best hyper parameters:',results['best_params'])
print('best objective:',results['best_objective'])
# Out:
# best hyper parameters: {'C': 0.14141448138204452, 'gamma': 1.108381123540644}
# best objective: 0.8337418300653594

# %%
print('Sample hyper parameters tried:',len(results['params_tried']))
print(results['params_tried'][:2])
# Out:
# Sample hyper parameters tried: 61
# [{'C': 6.803175982928234e-06, 'gamma': 3.8760537843338168}, {'C': 1.0737868597766003e-06, 'gamma': 0.1037808098068175}]

# %%
print('Sample objective values',len(results['objective_values']))
print(results['objective_values'][:5])
# Out:
# Sample objective values 61
# [0.8141339869281046, 0.7732843137254902, 0.7802287581699346, 0.8141339869281046, 0.8141339869281046]

# %% [markdown]
# # Plotting the variation in objective values of the tried results

# %%
Size = 201 

from matplotlib import pyplot as plt
fig = plt.figure(figsize=(30,5))
plt.title('Variation of Objective',fontsize=20)
plt.plot(results['objective_values'][:Size],lw=4,label='BL')
plt.xlabel('Configuration', fontsize=25)
plt.ylabel('objective_values',fontsize=25)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.legend(prop={'size': 30})
plt.show()

# %% [markdown]
# # Plotting the variation of Max objective values of the tried results

# %%
Size = 30 

import numpy as np

results_obj = np.array(results['objective_values'])

y_max=[]
for i in range(results_obj.shape[0]):
    y_max.append(np.max(results_obj[:i+1]))

from matplotlib import pyplot as plt
fig = plt.figure(figsize=(30,5))
plt.title('Max variation of Objective',fontsize=20)
plt.plot(y_max[:Size],lw=4,label='BL')
plt.xlabel('Configurations', fontsize=25)
plt.ylabel('objective_values',fontsize=25)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.legend(prop={'size': 30})
plt.show()

# %% [markdown]
# # See the Result

# %%
import pprint
pp = pprint.PrettyPrinter(indent=4)
pp.pprint(results)
# Out:
# {   'best_objective': 0.8337418300653594,
#     'best_params': {'C': 0.15437624798108956, 'gamma': 1.109582126269499},
#     'objective_values': [   0.8267973856209151,
#                             0.8010620915032679,
#                             0.8206699346405228,
#                             0.8141339869281046,
#                             0.8133169934640523,
#                             0.8141339869281046,
#                             0.8075980392156863,
#                             0.7732843137254902,
#                             0.8267973856209151,
#                             0.8141339869281046,
#                             0.8075980392156863,
#                             0.8071895424836603,
#                             0.8141339869281046,
#                             0.8267973856209151,
#                             0.8206699346405228,
#                             0.8267973856209151,
#                             0.8141339869281046,
#                             0.8063725490196078,
#                             0.8063725490196078,
#                             0.8071895424836603,
#                             0.8075980392156863,
#                             0.8141339869281046,
#                             0.8141339869281046,
#                             0.8141339869281046,
#                             0.8337418300653594,
#                             0.8133169934640523,
#                             0.8075980392156863,
#                             0.8141339869281046,
#                             0.8141339869281046,
#                             0.8133169934640523,
#                             0.8075980392156863,
#                             0.8337418300653594,
#                             0.7998366013071895,
#                             0.8198529411764706,
#                             0.8141339869281046,
#                             0.8141339869281046,
#                             0.8075980392156863,
#                             0.8206699346405228,
#                             0.8337418300653594,
#                             0.8337418300653594,
#                             0.8071895424836603,
#                             0.7998366013071895,
#                             0.8075980392156863,
#                             0.8337418300653594,
#                             0.8337418300653594,
#                             0.8337418300653594,
#                             0.812908496732026,
#                             0.8141339869281046,
#                             0.8206699346405228,
#                             0.8141339869281046,
#                             0.8075980392156863,
#                             0.8267973856209151,
#                             0.8337418300653594,
#                             0.8267973856209151,
#                             0.8337418300653594,
#                             0.7933006535947712,
#                             0.8141339869281046,
#                             0.8141339869281046,
#                             0.8141339869281046,
#                             0.8141339869281046,
#                             0.8071895424836603],
#     'params_tried': [   {   'C': 0.0036934030607970597,
#                             'gamma': 1.247799959755476},
#                         {'C': 0.5326777284483912, 'gamma': 4.075735075985743},
#                         {'C': 5.677151553391925e-07, 'gamma': 2.67116639856545},
#                         {   'C': 7.149128288622009e-05,
#                             'gamma': 3.010504960630256},
#                         {'C': 0.9548285209885206, 'gamma': 0.11250562929684929},
#                         {'C': 0.8459309768713487, 'gamma': 1.8066426862846696},
#                         {'C': 0.9140599442819524, 'gamma': 2.577308003622082},
#                         {   'C': 3.371370806443806e-06,
#                             'gamma': 0.1014439744197281},
#                         {   'C': 1.3333832805176402e-06,
#                             'gamma': 1.8269769708318289},
#                         {'C': 0.2835124558961926, 'gamma': 1.6767019205977571},
#                         {   'C': 0.0001519088220401006,
#                             'gamma': 4.083624516913978},
#                         {'C': 0.9887926312684057, 'gamma': 0.749820569867356},
#                         {'C': 0.9869025351393892, 'gamma': 3.5354796464816842},
#                         {   'C': 1.6075133628673125e-07,
#                             'gamma': 1.5135070307137584},
#                         {   'C': 4.985580085315328e-07,
#                             'gamma': 2.1980596387624716},
#                         {   'C': 2.49819119690832e-06,
#                             'gamma': 1.4096997655925283},
#                         {'C': 0.928773961933718, 'gamma': 4.041276529902251},
#                         {'C': 0.38328836072931183, 'gamma': 0.421656385638025},
#                         {   'C': 2.2920060243615987e-07,
#                             'gamma': 0.7476639550646177},
#                         {'C': 0.6094629819957352, 'gamma': 1.1778526768002076},
#                         {'C': 0.45822571626776926, 'gamma': 3.0567027190428964},
#                         {   'C': 1.3488229174515897e-07,
#                             'gamma': 3.669284255546337},
#                         {'C': 0.5174464507451795, 'gamma': 2.1998068954533596},
#                         {'C': 0.9691682356755389, 'gamma': 3.107953681642069},
#                         {'C': 0.15437624798108956, 'gamma': 1.109582126269499},
#                         {'C': 0.46638885837192157, 'gamma': 0.7225255042267457},
#                         {'C': 0.9713961067485137, 'gamma': 2.3232200442221935},
#                         {'C': 0.28113285194848453, 'gamma': 2.5765617061374346},
#                         {'C': 0.934478611733374, 'gamma': 1.5019170961631483},
#                         {'C': 0.6217747716097664, 'gamma': 0.17613050410072476},
#                         {'C': 0.51696204975999, 'gamma': 3.56082789825432},
#                         {'C': 0.2178961975279238, 'gamma': 1.246085341411344},
#                         {'C': 0.9550885505556186, 'gamma': 0.3834201757436645},
#                         {'C': 0.17412410189001898, 'gamma': 0.9267046958484174},
#                         {'C': 0.24108695495345417, 'gamma': 3.8921140612862124},
#                         {'C': 0.1580059258966926, 'gamma': 3.4234441364616046},
#                         {'C': 0.725242899868982, 'gamma': 3.798521002741848},
#                         {'C': 0.17054146199073894, 'gamma': 2.0466895090303994},
#                         {'C': 0.1306799720725912, 'gamma': 1.369791414029724},
#                         {'C': 0.09102947482644747, 'gamma': 1.1445016804537604},
#                         {'C': 0.932811667995263, 'gamma': 1.1238052616319418},
#                         {   'C': 0.32658068494716624,
#                             'gamma': 0.12117747291125883},
#                         {'C': 0.6535588576189509, 'gamma': 2.6715453849423114},
#                         {'C': 0.11197148067376736, 'gamma': 1.2531529801177173},
#                         {'C': 0.17241147259944917, 'gamma': 1.3017532123348614},
#                         {'C': 0.10367763061006563, 'gamma': 1.1883586381354063},
#                         {'C': 0.8018408947073234, 'gamma': 0.615096641148653},
#                         {'C': 0.17677307791903568, 'gamma': 2.902179955434326},
#                         {'C': 0.13854764480565993, 'gamma': 2.3641564229809426},
#                         {'C': 0.9227264294021792, 'gamma': 1.8916886366344325},
#                         {'C': 0.7019222466170011, 'gamma': 3.4010325661811693},
#                         {   'C': 4.3870428125696136e-07,
#                             'gamma': 1.024277370320061},
#                         {'C': 0.1155799528868214, 'gamma': 1.4646347161019762},
#                         {'C': 0.1625178658570493, 'gamma': 1.2482970271830247},
#                         {'C': 0.15190592733511848, 'gamma': 1.2398954345617548},
#                         {   'C': 1.2865901229913011e-06,
#                             'gamma': 0.4000209773083995},
#                         {'C': 0.5583124476196448, 'gamma': 1.446400701277291},
#                         {   'C': 5.657361105832184e-06,
#                             'gamma': 3.308987393384284},
#                         {'C': 0.9851068019153254, 'gamma': 2.8846360321279834},
#                         {'C': 0.5817905656545579, 'gamma': 1.9350934745759538},
#                         {'C': 0.7344860500229329, 'gamma': 0.9245382516437267}],
#     'random_params': [{'C': 0.0036934030607970597, 'gamma': 1.247799959755476}],
#     'random_params_objective': [0.8267973856209151]}
