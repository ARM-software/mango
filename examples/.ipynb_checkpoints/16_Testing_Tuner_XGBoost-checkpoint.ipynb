# %% [markdown]
# # Testing the Tuner Abstraction

# %%
import sys
sys.path.append('/Users/sansan01/Learning/Bayesian_Learning/Exp-16/AutoTuner/')

# %%
from tuner import Tuner

# %% [markdown]
# # Classifier Configuration

# %%
from scipy.stats import uniform


clf_name = 'XGBClassifier'
dataset_name = 'load_wine'

param_dict = {"learning_rate": uniform(0, 1),
              "gamma": uniform(0, 5),
              "max_depth": range(1,50),
              "n_estimators": range(1,300),
              "min_child_weight": range(1,10)}

# %%
conf_Dict = dict()
conf_Dict['clf_name']=clf_name
conf_Dict['dataset_name'] = dataset_name
conf_Dict['param_dict']=param_dict

conf_Dict['num_iteration'] = 30

# %% [markdown]
# #  Tuner functions

# %%
tuner_local = Tuner(conf_Dict)

# %%
tuner_local.get_conf()
# Out:
# {'scheduler': 'local',
#  'domain_size': 10000,
#  'initial_random': 1,
#  'num_iteration': 30,
#  'objective': 'maximize',
#  'batch_size': 1,
#  'param_dict': {'learning_rate': <scipy.stats._distn_infrastructure.rv_frozen at 0x12165c898>,
#   'gamma': <scipy.stats._distn_infrastructure.rv_frozen at 0x12165cd30>,
#   'max_depth': range(1, 50),
#   'n_estimators': range(1, 300),
#   'min_child_weight': range(1, 10)},
#  'clf_name': 'XGBClassifier',
#  'dataset_name': 'load_wine'}

# %%
results = tuner_local.run()

# %% [markdown]
# # Inspect the results

# %%
print('best hyper parameters:',results['best_hyper_parameter'])
print('best objective:',results['best_objective'])
# Out:
# best hyper parameters: {'gamma': 0.18462940360613356, 'learning_rate': 0.2767661774226027, 'max_depth': 48, 'min_child_weight': 1, 'n_estimators': 82}
# best objective: 0.9220306513409962

# %%
print('Hyper parameters tried:',len(results['hyper_parameters_tried']))
print(results['hyper_parameters_tried'][:2])
# Out:
# Hyper parameters tried: 30
# [{'gamma': 1.3085528521950245, 'learning_rate': 0.2962838797858771, 'max_depth': 6, 'min_child_weight': 4, 'n_estimators': 288}, {'gamma': 3.8327799351543925, 'learning_rate': 0.36300023338501985, 'max_depth': 1, 'min_child_weight': 1, 'n_estimators': 4}]

# %%
print('Vairation in the objective values')
print(results['objective_values'])
# Out:
# Vairation in the objective values
# [0.8772030651340996, 0.8549808429118775, 0.9053639846743295, 0.8831417624521073, 0.8385057471264368, 0.8773946360153256, 0.8942528735632185, 0.8660919540229886, 0.8716475095785441, 0.9220306513409962, 0.9109195402298851, 0.9053639846743295, 0.8940613026819925, 0.8773946360153256, 0.8716475095785441, 0.8660919540229886, 0.8883141762452107, 0.899616858237548, 0.860536398467433, 0.9051724137931035, 0.8775862068965518, 0.8662835249042146, 0.8940613026819925, 0.899616858237548, 0.8827586206896552, 0.8885057471264369, 0.8716475095785441, 0.9109195402298851, 0.9053639846743295, 0.8885057471264369]

# %% [markdown]
# # Plotting the variation in objective values of the tried results

# %%
Size = 30 

from matplotlib import pyplot as plt
fig = plt.figure(figsize=(30,5))
plt.title('Variation of Objective',fontsize=20)
plt.plot(results['objective_values'][:Size],lw=4,label='BL')
plt.xlabel('Iterations', fontsize=25)
plt.ylabel('objective_values',fontsize=25)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.legend(prop={'size': 30})
plt.show()
